# %% [markdown]
# ## <strong>9. RESTful API를 이용한 데이터 취득</strong>

# %%
import requests  # HTTP 통신 라이브러리
import matplotlib.pyplot as plt # 데이터 시각화
import time # API 요청 제한(Rate Limit) 우회를 위한 시간 제어

# %%
# 1. 상위 100개 코인 정보 가져오기 (Data Acquisition 단계)
def get_top_100_coins():
    """
    CoinGecko API를 통해 시장의 원천 데이터(Raw Data)를 취득
    """
    url = "https://api.coingecko.com/api/v3/coins/markets"
    
    # API 요청 파라미터 설정
    params = {
        "vs_currency": "usd",        # 통화 단위: USD
        "order": "market_cap_desc",  # 정렬 기준: 시가총액 내림차순
        "per_page": 100,             # 취득할 데이터 양: 100개
        "page": 1,                   # 페이지 번호
        "sparkline": False           # 데이터 부하를 줄이기 위해 그래프 데이터 제외
    }
    
    # RESTful API 호출 (HTTP GET 방식)
    response = requests.get(url, params=params)
    
    # 응답받은 JSON 데이터를 파이썬 객체로 변환
    return response.json()

# %%
# 2. 특정 코인의 시가총액 추이 가져오기
def get_market_chart(coin_id):
    """
    특정 코인의 ID를 사용하여 시계열 데이터를 요청
    """
    url = f"https://api.coingecko.com/api/v3/coins/{coin_id}/market_chart"
    params = {
        "vs_currency": "usd",
        "days": 365,          # 데이터 범위: 최근 365일
        "interval": "daily"   # 데이터 간격: 일 단위 (데이터 정제 과정)
    }
    
    response = requests.get(url, params=params)
    
    # HTTP 상태 코드가 200(성공)일 경우에만 데이터 반환 (예외 처리)
    if response.status_code == 200:
        return response.json()["market_caps"]
    else:
        # 데이터 취득 실패 시 빈 리스트 반환
        return []

# %%
# 3. 시각화 함수 
def plot_market_caps(coin_data):
    """
    가공된 데이터를 바탕으로 분석용 차트를 생성
    """
    plt.figure(figsize=(16, 10))

    for coin_name, market_caps in coin_data.items():
        if not market_caps:
            continue
            
        timestamps = [cap[0] for cap in market_caps] # x축: 타임스탬프
        
        # 데이터 스케일링: 가독성을 위해 달러 단위를 10억(Billion) 단위로 변환
        values = [cap[1] / 1e9 for cap in market_caps] 
        
        plt.plot(timestamps, values, label=coin_name)

    # 시각화
    plt.title("Top 100 Alt Coins - Market Cap Trend (Last 365 Days)")
    plt.xlabel("Timestamp")
    plt.ylabel("Market Cap (Billion USD)")
    plt.xticks(rotation=45)
    plt.legend(fontsize="small", loc="upper left", ncol=2)
    plt.tight_layout()
    plt.grid(True)
    plt.show()

# %%
# --- 메인 실행 흐름 ---

print("🚀 상위 100개 코인 정보를 불러오는 중...")
all_coins = get_top_100_coins()

# 데이터 필터링: 시장 지배력이 너무 큰 BTC, ETH를 제외하여 주요 알트코인들의 추이를 비교
coins = all_coins[2:] 

coin_market_data = {}

# 반복문을 통한 대량 데이터 취득
for i, coin in enumerate(coins):
    coin_id = coin["id"]
    coin_name = coin["name"]
    
    print(f"📈 데이터 수집 중: {coin_name} ({i+1}/100)")
    market_caps = get_market_chart(coin_id)
    
    # 딕셔너리에 데이터 적재
    coin_market_data[coin_name] = market_caps
    
    # API 요청 제한 우회
    time.sleep(1.2) 

    # 실습 효율을 위해 상위 4개 알트코인만 수집 후 중단
    if i >= 3: 
        break
# Out:
# 🚀 상위 100개 코인 정보를 불러오는 중...
# 📈 데이터 수집 중: Tether (1/100)
# 📈 데이터 수집 중: BNB (2/100)
# 📈 데이터 수집 중: USDC (3/100)
# 📈 데이터 수집 중: XRP (4/100)

# %%
# 최종 가공된 데이터를 시각화
plot_market_caps(coin_market_data)

# %%
# get_top_100_coins() 응답 내용(JSON) 확인
coins
# Out:
# [{'id': 'tether',
#   'symbol': 'usdt',
#   'name': 'Tether',
#   'image': 'https://coin-images.coingecko.com/coins/images/325/large/Tether.png?1696501661',
#   'current_price': 0.999458,
#   'market_cap': 186475330019,
#   'market_cap_rank': 3,
#   'fully_diluted_valuation': 191939303197,
#   'total_volume': 34174334925,
#   'high_24h': 0.999617,
#   'low_24h': 0.999343,
#   'price_change_24h': 3.557e-05,
#   'price_change_percentage_24h': 0.00356,
#   'market_cap_change_24h': 4532004,
#   'market_cap_change_percentage_24h': 0.00243,
#   'circulating_supply': 186576637808.0025,
#   'total_supply': 192043579438.5862,
#   'max_supply': None,
#   'ath': 1.32,
#   'ath_change_percentage': -24.45247,
#   'ath_date': '2018-07-24T00:00:00.000Z',
#   'atl': 0.572521,
#   'atl_change_percentage': 74.59025,
#   'atl_date': '2015-03-02T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2026-06-14T06:57:37.479Z'},
#  {'id': 'binancecoin',
#   'symbol': 'bnb',
#   'name': 'BNB',
#   'image': 'https://coin-images.coingecko.com/coins/images/825/large/bnb-icon2_2x.png?1696501970',
#   'current_price': 610.63,
#   'market_cap': 82287594701,
#   'market_cap_rank': 4,
#   'fully_diluted_valuation': 82287594701,
#   'total_volume': 419367307,
#   'high_24h': 611.65,
#   'low_24h': 601.75,
#   'price_change_24h': 8.17,
#   'price_change_percentage_24h': 1.35589,
#   'market_cap_change_24h': 1113037462,
#   'market_cap_change_percentage_24h': 1.37117,
#   'circulating_supply': 134783739.49,
#   'total_supply': 134783739.49,
#   'max_supply': 200000000.0,
#   'ath': 1369.99,
#   'ath_change_percentage': -55.4283,
#   'ath_date': '2025-10-13T08:41:24.131Z',
#   'atl': 0.0398177,
#   'atl_change_percentage': 1533460.64448,
#   'atl_date': '2017-10-19T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2026-06-14T06:57:37.818Z'},
#  {'id': 'usd-coin',
#   'symbol': 'usdc',
#   'name': 'USDC',
#   'image': 'https://coin-images.coingecko.com/coins/images/6319/large/USDC.png?1769615602',
#   'current_price': 0.999757,
#   'market_cap': 74854647478,
#   'market_cap_rank': 5,
#   'fully_diluted_valuation': 74854655902,
#   'total_volume': 5699012337,
#   'high_24h': 1.0,
#   'low_24h': 0.99973,
#   'price_change_24h': -6.3445984842869e-05,
#   'price_change_percentage_24h': -0.00635,
#   'market_cap_change_24h': 46504742,
#   'market_cap_change_percentage_24h': 0.06217,
#   'circulating_supply': 74869711813.81313,
#   'total_supply': 74869720239.05861,
#   'max_supply': None,
#   'ath': 1.043,
#   'ath_change_percentage': -4.1803,
#   'ath_date': '2018-11-15T00:00:00.000Z',
#   'atl': 0.877647,
#   'atl_change_percentage': 13.92337,
#   'atl_date': '2023-03-11T08:02:13.981Z',
#   'roi': None,
#   'last_updated': '2026-06-14T06:57:37.871Z'},
#  {'id': 'ripple',
#   'symbol': 'xrp',
#   'name': 'XRP',
#   'image': 'https://coin-images.coingecko.com/coins/images/44/large/xrp-symbol-white-128.png?1696501442',
#   'current_price': 1.15,
#   'market_cap': 71165807496,
#   'market_cap_rank': 6,
#   'fully_diluted_valuation': 114667404187,
#   'total_volume': 1090610453,
#   'high_24h': 1.16,
#   'low_24h': 1.13,
#   'price_change_24h': 0.00938909,
#   'price_change_percentage_24h': 0.82601,
#   'market_cap_change_24h': 619917122,
#   'market_cap_change_percentage_24h': 0.87874,
#   'circulating_supply': 62053900985.0,
#   'total_supply': 99985653167.0,
#   'max_supply': 100000000000.0,
#   'ath': 3.65,
#   'ath_change_percentage': -68.5697,
#   'ath_date': '2025-07-18T03:40:53.808Z',
#   'atl': 0.00268621,
#   'atl_change_percentage': 42564.9023,
#   'atl_date': '2014-05-22T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2026-06-14T06:57:39.690Z'},
#  {'id': 'solana',
#   'symbol': 'sol',
#   'name': 'Solana',
#   'image': 'https://coin-images.coingecko.com/coins/images/4128/large/solana.png?1718769756',
#   'current_price': 68.14,
#   'market_cap': 39500604573,
#   'market_cap_rank': 7,
#   'fully_diluted_valuation': 42803304352,
#   'total_volume': 1710307134,
#   'high_24h': 69.36,
#   'low_24h': 67.01,
#   'price_change_24h': 1.007,
#   'price_change_percentage_24h': 1.49972,
#   'market_cap_change_24h': 564875886,
#   'market_cap_change_percentage_24h': 1.45079,
#   'circulating_supply': 579823625.21767,
#   'total_supply': 628303474.5701282,
#   'max_supply': None,
#   'ath': 293.31,
#   'ath_change_percentage': -76.7681,
#   'ath_date': '2025-01-19T11:15:27.957Z',
#   'atl': 0.500801,
#   'atl_change_percentage': 13506.58532,
#   'atl_date': '2020-05-11T19:35:23.449Z',
#   'roi': None,
#   'last_updated': '2026-06-14T06:57:37.496Z'},
#  {'id': 'tron',
#   'symbol': 'trx',
#   'name': 'TRON',
#   'image': 'https://coin-images.coingecko.com/coins/images/1094/large/photo_2026-04-13_09-59-16.png?1776048311',
#   'current_price': 0.315537,
#   'market_cap': 29918288321,
#   'market_cap_rank': 8,
#   'fully_diluted_valuation': 29919273627,
#   'total_volume': 406051601,
#   'high_24h': 0.318261,
#   'low_24h': 0.315075,
#   'price_change_24h': 0.00015893,
#   'price_change_percentage_24h': 0.05039,
#   'market_cap_change_24h': 12279873,
#   'market_cap_change_percentage_24h': 0.04106,
#   'circulating_supply': 94826790531.35327,
#   'total_supply': 94829913484.57666,
#   'max_supply': None,
#   'ath': 0.431288,
#   'ath_change_percentage': -26.83841,
#   'ath_date': '2024-12-04T00:10:40.323Z',
#   'atl': 0.00180434,
#   'atl_change_percentage': 17387.67617,
#   'atl_date': '2017-11-12T00:00:00.000Z',
#   'roi': {'times': 165.0723273952233,
#    'currency': 'usd',
#    'percentage': 16507.232739522333},
#   'last_updated': '2026-06-14T06:57:30.250Z'},
#  {'id': 'figure-heloc',
#   'symbol': 'figr_heloc',
#   'name': 'Figure Heloc',
#   'image': 'https://coin-images.coingecko.com/coins/images/68480/large/figure.png?1755863954',
#   'current_price': 1.018,
#   'market_cap': 19162760760,
#   'market_cap_rank': 9,
#   'fully_diluted_valuation': 19162760760,
#   'total_volume': 95054,
#   'high_24h': 1.035,
#   'low_24h': 1.018,
#   'price_change_24h': -0.013310699999999898,
#   'price_change_percentage_24h': -1.29097,
#   'market_cap_change_24h': -212538536.87965775,
#   'market_cap_change_percentage_24h': -1.09696,
#   'circulating_supply': 18828522477.217,
#   'total_supply': 18828522477.217,
#   'max_supply': None,
#   'ath': 1.049,
#   'ath_change_percentage': -2.98983,
#   'ath_date': '2026-03-09T17:00:25.937Z',
#   'atl': 0.155357,
#   'atl_change_percentage': 555.10683,
#   'atl_date': '2025-10-31T14:27:24.456Z',
#   'roi': None,
#   'last_updated': '2026-06-14T04:53:25.994Z'},
#  {'id': 'dogecoin',
#   'symbol': 'doge',
#   'name': 'Dogecoin',
#   'image': 'https://coin-images.coingecko.com/coins/images/5/large/dogecoin.png?1696501409',
#   'current_price': 0.087428,
#   'market_cap': 13521299939,
#   'market_cap_rank': 10,
#   'fully_diluted_valuation': 14895090617,
#   'total_volume': 559361856,
#   'high_24h': 0.088641,
#   'low_24h': 0.086471,
#   'price_change_24h': 0.00078899,
#   'price_change_percentage_24h': 0.91067,
#   'market_cap_change_24h': 125419900,
#   'market_cap_change_percentage_24h': 0.93626,
#   'circulating_supply': 154652386383.7052,
#   'total_supply': 170365373126.579,
#   'max_supply': None,
#   'ath': 0.731578,
#   'ath_change_percentage': -88.04944,
#   'ath_date': '2021-05-08T05:08:23.458Z',
#   'atl': 8.69e-05,
#   'atl_change_percentage': 100502.87842,
#   'atl_date': '2015-05-06T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2026-06-14T06:57:25.558Z'},
#  {'id': 'hyperliquid',
#   'symbol': 'hype',
#   'name': 'Hyperliquid',
#   'image': 'https://coin-images.coingecko.com/coins/images/50882/large/hyperliquid.jpg?1729431300',
#   'current_price': 59.75,
#   'market_cap': 13289164441,
#   'market_cap_rank': 11,
#   'fully_diluted_valuation': 57071150697,
#   'total_volume': 491877990,
#   'high_24h': 61.13,
#   'low_24h': 57.92,
#   'price_change_24h': 0.995708,
#   'price_change_percentage_24h': 1.6946,
#   'market_cap_change_24h': 217455584,
#   'market_cap_change_percentage_24h': 1.66356,
#   'circulating_supply': 222445714.0741414,
#   'total_supply': 955307079.4341414,
#   'max_supply': 1000000000.0,
#   'ath': 75.48,
#   'ath_change_percentage': -20.83525,
#   'ath_date': '2026-06-02T03:26:51.695Z',
#   'atl': 3.81,
#   'atl_change_percentage': 1468.85281,
#   'atl_date': '2024-11-29T09:30:30.871Z',
#   'roi': None,
#   'last_updated': '2026-06-14T06:57:26.241Z'},
#  {'id': 'usds',
#   'symbol': 'usds',
#   'name': 'USDS',
#   'image': 'https://coin-images.coingecko.com/coins/images/39926/large/usds.webp?1726666683',
#   'current_price': 0.999655,
#   'market_cap': 10563904818,
#   'market_cap_rank': 12,
#   'fully_diluted_valuation': 10563904818,
#   'total_volume': 15218651,
#   'high_24h': 0.999843,
#   'low_24h': 0.999577,
#   'price_change_24h': -1.2780621687303e-05,
#   'price_change_percentage_24h': -0.00128,
#   'market_cap_change_24h': -35154831.47659111,
#   'market_cap_change_percentage_24h': -0.33168,
#   'circulating_supply': 10567433693.11222,
#   'total_supply': 10567433693.11222,
#   'max_supply': None,
#   'ath': 1.15,
#   'ath_change_percentage': -13.22684,
#   'ath_date': '2026-04-02T07:21:14.655Z',
#   'atl': 0.948265,
#   'atl_change_percentage': 5.42448,
#   'atl_date': '2024-10-03T13:19:28.826Z',
#   'roi': None,
#   'last_updated': '2026-06-14T06:57:39.336Z'},
#  {'id': 'leo-token',
#   'symbol': 'leo',
#   'name': 'LEO Token',
#   'image': 'https://coin-images.coingecko.com/coins/images/8418/large/leo-token.png?1696508607',
#   'current_price': 9.75,
#   'market_cap': 8937185282,
#   'market_cap_rank': 13,
#   'fully_diluted_valuation': 9566837854,
#   'total_volume': 572698,
#   'high_24h': 9.88,
#   'low_24h': 9.43,
#   'price_change_24h': 0.199271,
#   'price_change_percentage_24h': 2.08574,
#   'market_cap_change_24h': 145877759,
#   'market_cap_change_percentage_24h': 1.65934,
#   'circulating_supply': 920394818.9,
#   'total_supply': 985239504.0,
#   'max_supply': None,
#   'ath': 10.57,
#   'ath_change_percentage': -7.91552,
#   'ath_date': '2026-05-04T09:45:26.809Z',
#   'atl': 0.799859,
#   'atl_change_percentage': 1116.83695,
#   'atl_date': '2019-12-24T15:14:35.376Z',
#   'roi': None,
#   'last_updated': '2026-06-14T06:57:34.672Z'},
#  {'id': 'rain',
#   'symbol': 'rain',
#   'name': 'Rain',
#   'image': 'https://coin-images.coingecko.com/coins/images/69134/large/Rain_logo_1_.png?1762952191',
#   'current_price': 0.01286009,
#   'market_cap': 8007938828,
#   'market_cap_rank': 14,
#   'fully_diluted_valuation': 14788323828,
#   'total_volume': 44739005,
#   'high_24h': 0.01305518,
#   'low_24h': 0.01277754,
#   'price_change_24h': -0.00014871002720252,
#   'price_change_percentage_24h': -1.14315,
#   'market_cap_change_24h': -92154127.7065239,
#   'market_cap_change_percentage_24h': -1.13769,
#   'circulating_supply': 622651695470.46,
#   'total_supply': 1149855799649.423,
#   'max_supply': 1150000000000.0,
#   'ath': 0.01478538,
#   'ath_change_percentage': -13.5755,
#   'ath_date': '2026-05-27T18:55:48.614Z',
#   'atl': 0.00222126,
#   'atl_change_percentage': 475.26804,
#   'atl_date': '2025-09-14T08:56:57.416Z',
#   'roi': None,
#   'last_updated': '2026-06-14T06:57:26.935Z'},
#  {'id': 'zcash',
#   'symbol': 'zec',
#   'name': 'Zcash',
#   'image': 'https://coin-images.coingecko.com/coins/images/486/large/circle-zcash-color.png?1696501740',
#   'current_price': 422.38,
#   'market_cap': 7082384340,
#   'market_cap_rank': 15,
#   'fully_diluted_valuation': 7082609411,
#   'total_volume': 447119838,
#   'high_24h': 427.96,
#   'low_24h': 406.92,
#   'price_change_24h': 8.4,
#   'price_change_percentage_24h': 2.0299,
#   'market_cap_change_24h': 134129964,
#   'market_cap_change_percentage_24h': 1.93041,
#   'circulating_supply': 16766184.5405448,
#   'total_supply': 16766717.3530448,
#   'max_supply': 21000000.0,
#   'ath': 3191.93,
#   'ath_change_percentage': -86.76714,
#   'ath_date': '2016-10-29T00:00:00.000Z',
#   'atl': 16.08,
#   'atl_change_percentage': 2526.743,
#   'atl_date': '2024-07-05T04:22:29.321Z',
#   'roi': None,
#   'last_updated': '2026-06-14T06:57:37.158Z'},
#  {'id': 'cardano',
#   'symbol': 'ada',
#   'name': 'Cardano',
#   'image': 'https://coin-images.coingecko.com/coins/images/975/large/cardano.png?1696502090',
#   'current_price': 0.1713,
#   'market_cap': 6374622700,
#   'market_cap_rank': 16,
#   'fully_diluted_valuation': 7709990029,
#   'total_volume': 317403106,
#   'high_24h': 0.175384,
#   'low_24h': 0.171331,
#   'price_change_24h': -0.000557197888720634,
#   'price_change_percentage_24h': -0.32422,
#   'market_cap_change_24h': -8627092.220051765,
#   'market_cap_change_percentage_24h': -0.13515,
#   'circulating_supply': 37206017184.44904,
#   'total_supply': 45000000000.0,
#   'max_supply': 45000000000.0,
#   'ath': 3.09,
#   'ath_change_percentage': -94.45076,
#   'ath_date': '2021-09-02T06:00:10.474Z',
#   'atl': 0.01925275,
#   'atl_change_percentage': 789.74298,
#   'atl_date': '2020-03-13T02:22:55.044Z',
#   'roi': None,
#   'last_updated': '2026-06-14T06:57:27.741Z'},
#  {'id': 'monero',
#   'symbol': 'xmr',
#   'name': 'Monero',
#   'image': 'https://coin-images.coingecko.com/coins/images/69/large/monero_logo.png?1696501460',
#   'current_price': 336.85,
#   'market_cap': 6318038728,
#   'market_cap_rank': 17,
#   'fully_diluted_valuation': 6318038728,
#   'total_volume': 95989970,
#   'high_24h': 348.95,
#   'low_24h': 335.47,
#   'price_change_24h': -4.377477410652659,
#   'price_change_percentage_24h': -1.28287,
#   'market_cap_change_24h': -75920789.20080376,
#   'market_cap_change_percentage_24h': -1.18738,
#   'circulating_supply': 18764732.4798589,
#   'total_supply': 18764732.4798589,
#   'max_supply': None,
#   'ath': 797.73,
#   'ath_change_percentage': -57.77447,
#   'ath_date': '2026-01-14T19:34:07.049Z',
#   'atl': 0.216177,
#   'atl_change_percentage': 155720.57041,
#   'atl_date': '2015-01-14T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2026-06-14T06:57:26.929Z'},
#  {'id': 'stellar',
#   'symbol': 'xlm',
#   'name': 'Stellar',
#   'image': 'https://coin-images.coingecko.com/coins/images/100/large/fmpFRHHQ_400x400.jpg?1735231350',
#   'current_price': 0.18637,
#   'market_cap': 6293091301,
#   'market_cap_rank': 18,
#   'fully_diluted_valuation': 9319815596,
#   'total_volume': 166970887,
#   'high_24h': 0.1918,
#   'low_24h': 0.185066,
#   'price_change_24h': -0.001030855423171717,
#   'price_change_percentage_24h': -0.55008,
#   'market_cap_change_24h': -27193629.369419098,
#   'market_cap_change_percentage_24h': -0.43026,
#   'circulating_supply': 33763093977.95284,
#   'total_supply': 50001786839.91258,
#   'max_supply': None,
#   'ath': 0.875563,
#   'ath_change_percentage': -78.71961,
#   'ath_date': '2018-01-03T00:00:00.000Z',
#   'atl': 0.00047612,
#   'atl_change_percentage': 39033.3893,
#   'atl_date': '2015-03-05T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2026-06-14T06:57:22.524Z'},
#  {'id': 'canton-network',
#   'symbol': 'cc',
#   'name': 'Canton',
#   'image': 'https://coin-images.coingecko.com/coins/images/70468/large/Canton-Ticker_%281%29.png?1762826299',
#   'current_price': 0.16055,
#   'market_cap': 6228454598,
#   'market_cap_rank': 19,
#   'fully_diluted_valuation': 6228454598,
#   'total_volume': 9244058,
#   'high_24h': 0.164022,
#   'low_24h': 0.159232,
#   'price_change_24h': -0.001938338657545058,
#   'price_change_percentage_24h': -1.19291,
#   'market_cap_change_24h': -69924365.32925129,
#   'market_cap_change_percentage_24h': -1.1102,
#   'circulating_supply': 38795822216.87168,
#   'total_supply': 38795822216.87168,
#   'max_supply': None,
#   'ath': 0.194152,
#   'ath_change_percentage': -17.40356,
#   'ath_date': '2026-02-03T08:02:08.411Z',
#   'atl': 0.059024,
#   'atl_change_percentage': 171.68984,
#   'atl_date': '2025-12-06T10:32:09.784Z',
#   'roi': None,
#   'last_updated': '2026-06-14T06:57:27.093Z'},
#  {'id': 'whitebit',
#   'symbol': 'wbt',
#   'name': 'WhiteBIT Coin',
#   'image': 'https://coin-images.coingecko.com/coins/images/27045/large/wbt_token.png?1696526096',
#   'current_price': 52.34,
#   'market_cap': 6190439694,
#   'market_cap_rank': 20,
#   'fully_diluted_valuation': 15395814341,
#   'total_volume': 41685873,
#   'high_24h': 52.7,
#   'low_24h': 51.98,
#   'price_change_24h': 0.336,
#   'price_change_percentage_24h': 0.64614,
#   'market_cap_change_24h': 44003661,
#   'market_cap_change_percentage_24h': 0.71592,
#   'circulating_supply': 118289410.0,
#   'total_supply': 294189409.0,
#   'max_supply': 400000000.0,
#   'ath': 64.11,
#   'ath_change_percentage': -18.28193,
#   'ath_date': '2025-12-10T20:16:13.582Z',
#   'atl': 3.06,
#   'atl_change_percentage': 1611.01283,
#   'atl_date': '2023-02-13T19:01:21.899Z',
#   'roi': None,
#   'last_updated': '2026-06-14T06:57:31.820Z'},
#  {'id': 'chainlink',
#   'symbol': 'link',
#   'name': 'Chainlink',
#   'image': 'https://coin-images.coingecko.com/coins/images/877/large/Chainlink_Logo_500.png?1760023405',
#   'current_price': 7.91,
#   'market_cap': 5754595504,
#   'market_cap_rank': 21,
#   'fully_diluted_valuation': 7914448822,
#   'total_volume': 152673369,
#   'high_24h': 8.03,
#   'low_24h': 7.9,
#   'price_change_24h': -0.006782681918892308,
#   'price_change_percentage_24h': -0.08563,
#   'market_cap_change_24h': -4373459.141138077,
#   'market_cap_change_percentage_24h': -0.07594,
#   'circulating_supply': 727099970.4255477,
#   'total_supply': 1000000000.0,
#   'max_supply': 1000000000.0,
#   'ath': 52.7,
#   'ath_change_percentage': -84.98186,
#   'ath_date': '2021-05-10T00:13:57.214Z',
#   'atl': 0.148183,
#   'atl_change_percentage': 5240.72062,
#   'atl_date': '2017-11-29T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2026-06-14T06:57:27.691Z'},
#  {'id': 'the-open-network',
#   'symbol': 'ton',
#   'name': 'Toncoin',
#   'image': 'https://coin-images.coingecko.com/coins/images/17980/large/photo_2024-09-10_17.09.00.jpeg?1725963446',
#   'current_price': 1.71,
#   'market_cap': 4573847559,
#   'market_cap_rank': 22,
#   'fully_diluted_valuation': 8873048326,
#   'total_volume': 139937821,
#   'high_24h': 1.76,
#   'low_24h': 1.68,
#   'price_change_24h': 0.02243443,
#   'price_change_percentage_24h': 1.33203,
#   'market_cap_change_24h': 62205716,
#   'market_cap_change_percentage_24h': 1.37878,
#   'circulating_supply': 2678889642.166509,
#   'total_supply': 5196919431.549329,
#   'max_supply': None,
#   'ath': 8.25,
#   'ath_change_percentage': -79.30252,
#   'ath_date': '2024-06-15T00:36:51.509Z',
#   'atl': 0.519364,
#   'atl_change_percentage': 228.91953,
#   'atl_date': '2021-09-21T00:33:11.092Z',
#   'roi': None,
#   'last_updated': '2026-06-14T06:57:23.708Z'},
#  {'id': 'ethena-usde',
#   'symbol': 'usde',
#   'name': 'Ethena USDe',
#   'image': 'https://coin-images.coingecko.com/coins/images/33613/large/usde.png?1733810059',
#   'current_price': 0.999504,
#   'market_cap': 4485024755,
#   'market_cap_rank': 23,
#   'fully_diluted_valuation': 4485024755,
#   'total_volume': 95143927,
#   'high_24h': 0.999762,
#   'low_24h': 0.999308,
#   'price_change_24h': 1.94e-05,
#   'price_change_percentage_24h': 0.00194,
#   'market_cap_change_24h': 722447,
#   'market_cap_change_percentage_24h': 0.01611,
#   'circulating_supply': 4487149228.891866,
#   'total_supply': 4487149228.891866,
#   'max_supply': None,
#   'ath': 1.034,
#   'ath_change_percentage': -3.33771,
#   'ath_date': '2025-12-09T17:10:12.652Z',
#   'atl': 0.929486,
#   'atl_change_percentage': 7.53375,
#   'atl_date': '2024-10-04T07:57:15.809Z',
#   'roi': None,
#   'last_updated': '2026-06-14T06:57:31.142Z'},
#  {'id': 'usd1-wlfi',
#   'symbol': 'usd1',
#   'name': 'USD1',
#   'image': 'https://coin-images.coingecko.com/coins/images/54977/large/USD1_1000x1000_transparent.png?1749297002',
#   'current_price': 1.0,
#   'market_cap': 4368166264,
#   'market_cap_rank': 24,
#   'fully_diluted_valuation': 4368236295,
#   'total_volume': 746200981,
#   'high_24h': 1.001,
#   'low_24h': 0.999943,
#   'price_change_24h': 0.00035065,
#   'price_change_percentage_24h': 0.03506,
#   'market_cap_change_24h': 37824911,
#   'market_cap_change_percentage_24h': 0.87349,
#   'circulating_supply': 4366112776.034947,
#   'total_supply': 4366182773.565371,
#   'max_supply': None,
#   'ath': 1.025,
#   'ath_change_percentage': -2.36811,
#   'ath_date': '2025-05-12T12:36:39.412Z',
#   'atl': 0.989633,
#   'atl_change_percentage': 1.10387,
#   'atl_date': '2025-10-01T08:51:32.103Z',
#   'roi': None,
#   'last_updated': '2026-06-14T06:57:29.065Z'},
#  {'id': 'dai',
#   'symbol': 'dai',
#   'name': 'Dai',
#   'image': 'https://coin-images.coingecko.com/coins/images/9956/large/Badge_Dai.png?1696509996',
#   'current_price': 0.999725,
#   'market_cap': 4192405378,
#   'market_cap_rank': 25,
#   'fully_diluted_valuation': 4192405378,
#   'total_volume': 75458224,
#   'high_24h': 0.999916,
#   'low_24h': 0.999561,
#   'price_change_24h': -9.397313387893e-06,
#   'price_change_percentage_24h': -0.00094,
#   'market_cap_change_24h': -9084280.65082407,
#   'market_cap_change_percentage_24h': -0.21622,
#   'circulating_supply': 4193460605.661051,
#   'total_supply': 4193460605.661051,
#   'max_supply': None,
#   'ath': 1.22,
#   'ath_change_percentage': -17.97678,
#   'ath_date': '2020-03-13T03:02:50.373Z',
#   'atl': 0.88196,
#   'atl_change_percentage': 13.36186,
#   'atl_date': '2023-03-11T07:50:50.514Z',
#   'roi': None,
#   'last_updated': '2026-06-14T06:57:27.623Z'},
#  {'id': 'bitcoin-cash',
#   'symbol': 'bch',
#   'name': 'Bitcoin Cash',
#   'image': 'https://coin-images.coingecko.com/coins/images/780/large/bitcoin-cash-circle.png?1696501932',
#   'current_price': 203.07,
#   'market_cap': 4070254642,
#   'market_cap_rank': 26,
#   'fully_diluted_valuation': 4070312379,
#   'total_volume': 107962127,
#   'high_24h': 209.25,
#   'low_24h': 203.03,
#   'price_change_24h': -1.9644750533666695,
#   'price_change_percentage_24h': -0.95814,
#   'market_cap_change_24h': -37400494.013745785,
#   'market_cap_change_percentage_24h': -0.91051,
#   'circulating_supply': 20047621.77165078,
#   'total_supply': 20047906.14665078,
#   'max_supply': 21000000.0,
#   'ath': 3785.82,
#   'ath_change_percentage': -94.63613,
#   'ath_date': '2017-12-20T00:00:00.000Z',
#   'atl': 76.93,
#   'atl_change_percentage': 163.9462,
#   'atl_date': '2018-12-16T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2026-06-14T06:57:33.534Z'},
#  {'id': 'memecore',
#   'symbol': 'm',
#   'name': 'MemeCore',
#   'image': 'https://coin-images.coingecko.com/coins/images/53247/large/square-bg-transparent.png?1752637478',
#   'current_price': 3.0,
#   'market_cap': 3942682863,
#   'market_cap_rank': 27,
#   'fully_diluted_valuation': 16159704649,
#   'total_volume': 8133026,
#   'high_24h': 3.05,
#   'low_24h': 2.94,
#   'price_change_24h': 0.04981317,
#   'price_change_percentage_24h': 1.6875,
#   'market_cap_change_24h': 68580698,
#   'market_cap_change_percentage_24h': 1.77023,
#   'circulating_supply': 1312606330.507049,
#   'total_supply': 5379923103.014275,
#   'max_supply': 10000000000.0,
#   'ath': 4.82,
#   'ath_change_percentage': -37.55947,
#   'ath_date': '2026-04-24T01:10:07.284Z',
#   'atl': 0.04746135,
#   'atl_change_percentage': 6238.40069,
#   'atl_date': '2025-07-04T03:56:17.448Z',
#   'roi': None,
#   'last_updated': '2026-06-14T06:57:25.770Z'},
#  {'id': 'hedera-hashgraph',
#   'symbol': 'hbar',
#   'name': 'Hedera',
#   'image': 'https://coin-images.coingecko.com/coins/images/3688/large/hbar.png?1696504364',
#   'current_price': 0.078634,
#   'market_cap': 3411414355,
#   'market_cap_rank': 28,
#   'fully_diluted_valuation': 3932626449,
#   'total_volume': 48223095,
#   'high_24h': 0.078992,
#   'low_24h': 0.077584,
#   'price_change_24h': 0.00103287,
#   'price_change_percentage_24h': 1.331,
#   'market_cap_change_24h': 47782900,
#   'market_cap_change_percentage_24h': 1.42057,
#   'circulating_supply': 43373231601.12233,
#   'total_supply': 50000000000.0,
#   'max_supply': 50000000000.0,
#   'ath': 0.569229,
#   'ath_change_percentage': -86.17422,
#   'ath_date': '2021-09-15T10:40:28.318Z',
#   'atl': 0.00986111,
#   'atl_change_percentage': 698.08777,
#   'atl_date': '2020-01-02T17:30:24.852Z',
#   'roi': None,
#   'last_updated': '2026-06-14T06:57:24.895Z'},
#  {'id': 'litecoin',
#   'symbol': 'ltc',
#   'name': 'Litecoin',
#   'image': 'https://coin-images.coingecko.com/coins/images/2/large/litecoin.png?1696501400',
#   'current_price': 44.13,
#   'market_cap': 3409851880,
#   'market_cap_rank': 29,
#   'fully_diluted_valuation': 3410245184,
#   'total_volume': 211283209,
#   'high_24h': 44.57,
#   'low_24h': 43.27,
#   'price_change_24h': 0.826777,
#   'price_change_percentage_24h': 1.90921,
#   'market_cap_change_24h': 66140372,
#   'market_cap_change_percentage_24h': 1.97805,
#   'circulating_supply': 77269264.48347135,
#   'total_supply': 77278176.98347135,
#   'max_supply': 84000000.0,
#   'ath': 410.26,
#   'ath_change_percentage': -89.24305,
#   'ath_date': '2021-05-10T03:13:07.904Z',
#   'atl': 1.15,
#   'atl_change_percentage': 3741.38344,
#   'atl_date': '2015-01-14T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2026-06-14T06:57:30.381Z'},
#  {'id': 'lab',
#   'symbol': 'lab',
#   'name': 'LAB',
#   'image': 'https://coin-images.coingecko.com/coins/images/70014/large/lab.png?1760352822',
#   'current_price': 10.0,
#   'market_cap': 3121312542,
#   'market_cap_rank': 30,
#   'fully_diluted_valuation': 9986830870,
#   'total_volume': 23220618,
#   'high_24h': 10.32,
#   'low_24h': 9.21,
#   'price_change_24h': 0.331689,
#   'price_change_percentage_24h': 3.43202,
#   'market_cap_change_24h': 89060011,
#   'market_cap_change_percentage_24h': 2.93709,
#   'circulating_supply': 312542846.0,
#   'total_supply': 1000000000.0,
#   'max_supply': 1000000000.0,
#   'ath': 27.3,
#   'ath_change_percentage': -63.35474,
#   'ath_date': '2026-06-02T21:05:47.499Z',
#   'atl': 0.074235,
#   'atl_change_percentage': 13376.77753,
#   'atl_date': '2025-12-02T03:30:39.644Z',
#   'roi': None,
#   'last_updated': '2026-06-14T06:57:27.177Z'},
#  {'id': 'sui',
#   'symbol': 'sui',
#   'name': 'Sui',
#   'image': 'https://coin-images.coingecko.com/coins/images/26375/large/sui-ocean-square.png?1727791290',
#   'current_price': 0.758753,
#   'market_cap': 3057165927,
#   'market_cap_rank': 31,
#   'fully_diluted_valuation': 7587531807,
#   'total_volume': 305713301,
#   'high_24h': 0.773833,
#   'low_24h': 0.753258,
#   'price_change_24h': 0.0041527,
#   'price_change_percentage_24h': 0.55032,
#   'market_cap_change_24h': 18196805,
#   'market_cap_change_percentage_24h': 0.59878,
#   'circulating_supply': 4029196852.454399,
#   'total_supply': 10000000000.0,
#   'max_supply': 10000000000.0,
#   'ath': 5.35,
#   'ath_change_percentage': -85.80859,
#   'ath_date': '2025-01-04T22:56:18.063Z',
#   'atl': 0.364846,
#   'atl_change_percentage': 107.96515,
#   'atl_date': '2023-10-19T10:40:30.078Z',
#   'roi': None,
#   'last_updated': '2026-06-14T06:57:28.202Z'},
#  {'id': 'hashnote-usyc',
#   'symbol': 'usyc',
#   'name': 'Circle USYC',
#   'image': 'https://coin-images.coingecko.com/coins/images/51054/large/Hashnote_SDYC_200x200.png?1730370965',
#   'current_price': 1.13,
#   'market_cap': 3007900705,
#   'market_cap_rank': 32,
#   'fully_diluted_valuation': 3007900705,
#   'total_volume': 562932,
#   'high_24h': None,
#   'low_24h': None,
#   'price_change_24h': None,
#   'price_change_percentage_24h': None,
#   'market_cap_change_24h': None,
#   'market_cap_change_percentage_24h': None,
#   'circulating_supply': 2671639466.20614,
#   'total_supply': 2671639466.20614,
#   'max_supply': None,
#   'ath': 1.13,
#   'ath_change_percentage': -0.0868,
#   'ath_date': '2026-05-30T16:21:04.142Z',
#   'atl': 1.026,
#   'atl_change_percentage': 9.72226,
#   'atl_date': '2024-12-05T22:31:20.475Z',
#   'roi': None,
#   'last_updated': '2026-06-04T17:58:24.894Z'},
#  {'id': 'shiba-inu',
#   'symbol': 'shib',
#   'name': 'Shiba Inu',
#   'image': 'https://coin-images.coingecko.com/coins/images/11939/large/shiba.png?1696511800',
#   'current_price': 5.01e-06,
#   'market_cap': 2952018230,
#   'market_cap_rank': 33,
#   'fully_diluted_valuation': 2953304013,
#   'total_volume': 84806234,
#   'high_24h': 5.07e-06,
#   'low_24h': 4.92e-06,
#   'price_change_24h': 9.0165e-08,
#   'price_change_percentage_24h': 1.833,
#   'market_cap_change_24h': 51723004,
#   'market_cap_change_percentage_24h': 1.78337,
#   'circulating_supply': 589243194906196.8,
#   'total_supply': 589499846110164.0,
#   'max_supply': None,
#   'ath': 8.616e-05,
#   'ath_change_percentage': -94.18617,
#   'ath_date': '2021-10-28T03:54:55.568Z',
#   'atl': 5.6366e-11,
#   'atl_change_percentage': 8886621.19884,
#   'atl_date': '2020-11-28T11:26:25.838Z',
#   'roi': None,
#   'last_updated': '2026-06-14T06:57:23.260Z'},
#  {'id': 'avalanche-2',
#   'symbol': 'avax',
#   'name': 'Avalanche',
#   'image': 'https://coin-images.coingecko.com/coins/images/12559/large/Avalanche_Circle_RedWhite_Trans.png?1696512369',
#   'current_price': 6.66,
#   'market_cap': 2874744259,
#   'market_cap_rank': 34,
#   'fully_diluted_valuation': 3085597607,
#   'total_volume': 113032033,
#   'high_24h': 6.76,
#   'low_24h': 6.62,
#   'price_change_24h': 0.02959957,
#   'price_change_percentage_24h': 0.44661,
#   'market_cap_change_24h': 11187168,
#   'market_cap_change_percentage_24h': 0.39067,
#   'circulating_supply': 431771961.1772119,
#   'total_supply': 463441061.1772119,
#   'max_supply': 720000000.0,
#   'ath': 144.96,
#   'ath_change_percentage': -95.4028,
#   'ath_date': '2021-11-21T14:18:56.538Z',
#   'atl': 2.8,
#   'atl_change_percentage': 137.91542,
#   'atl_date': '2020-12-31T13:15:21.540Z',
#   'roi': None,
#   'last_updated': '2026-06-14T06:57:23.304Z'},
#  {'id': 'paypal-usd',
#   'symbol': 'pyusd',
#   'name': 'PayPal USD',
#   'image': 'https://coin-images.coingecko.com/coins/images/31212/large/PYUSD_Token_Logo_2x.png?1765987788',
#   'current_price': 0.999991,
#   'market_cap': 2774034700,
#   'market_cap_rank': 35,
#   'fully_diluted_valuation': 2771933632,
#   'total_volume': 25489264,
#   'high_24h': 1.0,
#   'low_24h': 0.99967,
#   'price_change_24h': 0.00030296,
#   'price_change_percentage_24h': 0.03031,
#   'market_cap_change_24h': 612225,
#   'market_cap_change_percentage_24h': 0.02207,
#   'circulating_supply': 2773893209.354034,
#   'total_supply': 2771792248.374034,
#   'max_supply': None,
#   'ath': 1.081,
#   'ath_change_percentage': -7.47576,
#   'ath_date': '2026-04-02T07:35:31.426Z',
#   'atl': 0.959426,
#   'atl_change_percentage': 4.23366,
#   'atl_date': '2024-12-05T22:31:13.430Z',
#   'roi': None,
#   'last_updated': '2026-06-14T06:57:32.032Z'},
#  {'id': 'near',
#   'symbol': 'near',
#   'name': 'NEAR Protocol',
#   'image': 'https://coin-images.coingecko.com/coins/images/10365/large/near.jpg?1696510367',
#   'current_price': 2.1,
#   'market_cap': 2730200329,
#   'market_cap_rank': 36,
#   'fully_diluted_valuation': 2730200346,
#   'total_volume': 303829989,
#   'high_24h': 2.17,
#   'low_24h': 2.01,
#   'price_change_24h': 0.076803,
#   'price_change_percentage_24h': 3.7889,
#   'market_cap_change_24h': 99870087,
#   'market_cap_change_percentage_24h': 3.79686,
#   'circulating_supply': 1298174504.0,
#   'total_supply': 1298174512.0,
#   'max_supply': None,
#   'ath': 20.44,
#   'ath_change_percentage': -89.6938,
#   'ath_date': '2022-01-16T22:09:45.873Z',
#   'atl': 0.526762,
#   'atl_change_percentage': 299.87533,
#   'atl_date': '2020-11-04T16:09:15.137Z',
#   'roi': None,
#   'last_updated': '2026-06-14T06:57:22.901Z'},
#  {'id': 'crypto-com-chain',
#   'symbol': 'cro',
#   'name': 'Cronos',
#   'image': 'https://coin-images.coingecko.com/coins/images/7310/large/cro_token_logo.png?1696507599',
#   'current_price': 0.060817,
#   'market_cap': 2726750731,
#   'market_cap_rank': 37,
#   'fully_diluted_valuation': 6002083210,
#   'total_volume': 7884894,
#   'high_24h': 0.061007,
#   'low_24h': 0.059607,
#   'price_change_24h': 0.00110243,
#   'price_change_percentage_24h': 1.84618,
#   'market_cap_change_24h': 49479634,
#   'market_cap_change_percentage_24h': 1.84814,
#   'circulating_supply': 44844572035.29445,
#   'total_supply': 98711205932.15799,
#   'max_supply': 100000000000.0,
#   'ath': 0.891544,
#   'ath_change_percentage': -93.17908,
#   'ath_date': '2021-11-24T00:00:00.000Z',
#   'atl': 0.0121196,
#   'atl_change_percentage': 401.76217,
#   'atl_date': '2019-02-08T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2026-06-14T06:57:27.543Z'},
#  {'id': 'global-dollar',
#   'symbol': 'usdg',
#   'name': 'Global Dollar',
#   'image': 'https://coin-images.coingecko.com/coins/images/51281/large/GDN_USDG_Token_200x200.png?1730484111',
#   'current_price': 0.999988,
#   'market_cap': 2641484239,
#   'market_cap_rank': 38,
#   'fully_diluted_valuation': 2641484239,
#   'total_volume': 39919289,
#   'high_24h': 1.0,
#   'low_24h': 0.999397,
#   'price_change_24h': 1.675e-05,
#   'price_change_percentage_24h': 0.00168,
#   'market_cap_change_24h': -30883.650837898254,
#   'market_cap_change_percentage_24h': -0.00117,
#   'circulating_supply': 2641559220.993756,
#   'total_supply': 2641559220.993756,
#   'max_supply': None,
#   'ath': 1.65,
#   'ath_change_percentage': -39.57062,
#   'ath_date': '2025-01-30T00:11:05.728Z',
#   'atl': 0.907561,
#   'atl_change_percentage': 10.16488,
#   'atl_date': '2024-11-11T23:55:50.604Z',
#   'roi': None,
#   'last_updated': '2026-06-14T06:57:37.589Z'},
#  {'id': 'bittensor',
#   'symbol': 'tao',
#   'name': 'Bittensor',
#   'image': 'https://coin-images.coingecko.com/coins/images/28452/large/ARUsPeNQ_400x400.jpeg?1696527447',
#   'current_price': 272.86,
#   'market_cap': 2625953741,
#   'market_cap_rank': 39,
#   'fully_diluted_valuation': 5745775490,
#   'total_volume': 639866957,
#   'high_24h': 279.72,
#   'low_24h': 218.75,
#   'price_change_24h': 54.11,
#   'price_change_percentage_24h': 24.7387,
#   'market_cap_change_24h': 528336981,
#   'market_cap_change_percentage_24h': 25.18749,
#   'circulating_supply': 9597491.0,
#   'total_supply': 21000000.0,
#   'max_supply': 21000000.0,
#   'ath': 757.6,
#   'ath_change_percentage': -63.99275,
#   'ath_date': '2024-03-07T18:45:36.466Z',
#   'atl': 30.83,
#   'atl_change_percentage': 784.8297,
#   'atl_date': '2023-05-14T08:57:53.732Z',
#   'roi': None,
#   'last_updated': '2026-06-14T06:57:24.105Z'},
#  {'id': 'tether-gold',
#   'symbol': 'xaut',
#   'name': 'Tether Gold',
#   'image': 'https://coin-images.coingecko.com/coins/images/10481/large/logo.png?1774627372',
#   'current_price': 4216.55,
#   'market_cap': 2583789881,
#   'market_cap_rank': 40,
#   'fully_diluted_valuation': 2984006497,
#   'total_volume': 150359472,
#   'high_24h': 4216.41,
#   'low_24h': 4199.62,
#   'price_change_24h': 15.05,
#   'price_change_percentage_24h': 0.35821,
#   'market_cap_change_24h': 9024673,
#   'market_cap_change_percentage_24h': 0.3505,
#   'circulating_supply': 612823.654532,
#   'total_supply': 707747.089,
#   'max_supply': None,
#   'ath': 5504.62,
#   'ath_change_percentage': -23.40755,
#   'ath_date': '2026-01-29T00:00:00.000Z',
#   'atl': 1447.84,
#   'atl_change_percentage': 191.20042,
#   'atl_date': '2020-03-19T13:45:41.821Z',
#   'roi': None,
#   'last_updated': '2026-06-14T06:57:22.914Z'},
#  {'id': 'blackrock-usd-institutional-digital-liquidity-fund',
#   'symbol': 'buidl',
#   'name': 'BlackRock USD Institutional Digital Liquidity Fund',
#   'image': 'https://coin-images.coingecko.com/coins/images/36291/large/blackrock.png?1711013223',
#   'current_price': 1.0,
#   'market_cap': 2382859933,
#   'market_cap_rank': 41,
#   'fully_diluted_valuation': 2382859933,
#   'total_volume': 0.0,
#   'high_24h': 1.0,
#   'low_24h': 1.0,
#   'price_change_24h': 0.0,
#   'price_change_percentage_24h': 0.0,
#   'market_cap_change_24h': 0.0,
#   'market_cap_change_percentage_24h': 0.0,
#   'circulating_supply': 2382859933.170449,
#   'total_supply': 2382859933.170449,
#   'max_supply': None,
#   'ath': 1.0,
#   'ath_change_percentage': 0.0,
#   'ath_date': '2025-02-12T05:00:10.912Z',
#   'atl': 1.0,
#   'atl_change_percentage': 0.0,
#   'atl_date': '2025-02-12T05:45:10.196Z',
#   'roi': None,
#   'last_updated': '2026-06-14T06:50:40.752Z'},
#  {'id': 'ondo-us-dollar-yield',
#   'symbol': 'usdy',
#   'name': 'Ondo US Dollar Yield',
#   'image': 'https://coin-images.coingecko.com/coins/images/31700/large/usdy_%281%29.png?1696530524',
#   'current_price': 1.13,
#   'market_cap': 2144587739,
#   'market_cap_rank': 42,
#   'fully_diluted_valuation': 2144587739,
#   'total_volume': 3487743,
#   'high_24h': 1.14,
#   'low_24h': 1.12,
#   'price_change_24h': -0.003362791681952082,
#   'price_change_percentage_24h': -0.29616,
#   'market_cap_change_24h': -6522192.98914361,
#   'market_cap_change_percentage_24h': -0.3032,
#   'circulating_supply': 1892862515.164264,
#   'total_supply': 1892862515.164264,
#   'max_supply': None,
#   'ath': 1.26,
#   'ath_change_percentage': -10.22025,
#   'ath_date': '2024-03-27T05:24:08.110Z',
#   'atl': 0.934184,
#   'atl_change_percentage': 21.38506,
#   'atl_date': '2024-01-14T11:40:50.825Z',
#   'roi': None,
#   'last_updated': '2026-06-14T06:57:26.762Z'},
#  {'id': 'audiera',
#   'symbol': 'beat',
#   'name': 'Audiera',
#   'image': 'https://coin-images.coingecko.com/coins/images/70428/large/audiera.png?1761964064',
#   'current_price': 6.81,
#   'market_cap': 1957929126,
#   'market_cap_rank': 43,
#   'fully_diluted_valuation': 6797971634,
#   'total_volume': 98754546,
#   'high_24h': 9.45,
#   'low_24h': 6.56,
#   'price_change_24h': -1.8202775660145694,
#   'price_change_percentage_24h': -21.09574,
#   'market_cap_change_24h': -532879755.7242117,
#   'market_cap_change_percentage_24h': -21.39384,
#   'circulating_supply': 288016666.0,
#   'total_supply': 1000000000.0,
#   'max_supply': 1000000000.0,
#   'ath': 10.99,
#   'ath_change_percentage': -37.32391,
#   'ath_date': '2026-06-12T17:05:48.421Z',
#   'atl': 0.067925,
#   'atl_change_percentage': 10040.47739,
#   'atl_date': '2025-11-02T03:31:34.370Z',
#   'roi': None,
#   'last_updated': '2026-06-14T06:57:27.227Z'},
#  {'id': 'pax-gold',
#   'symbol': 'paxg',
#   'name': 'PAX Gold',
#   'image': 'https://coin-images.coingecko.com/coins/images/9519/large/paxgold.png?1696509604',
#   'current_price': 4225.79,
#   'market_cap': 1930726965,
#   'market_cap_rank': 44,
#   'fully_diluted_valuation': 1930726965,
#   'total_volume': 52009499,
#   'high_24h': 4226.42,
#   'low_24h': 4210.16,
#   'price_change_24h': 13.34,
#   'price_change_percentage_24h': 0.31658,
#   'market_cap_change_24h': 6124342,
#   'market_cap_change_percentage_24h': 0.31821,
#   'circulating_supply': 456894.511,
#   'total_supply': 456894.511,
#   'max_supply': None,
#   'ath': 5619.09,
#   'ath_change_percentage': -24.79251,
#   'ath_date': '2026-01-29T06:30:56.612Z',
#   'atl': 1399.64,
#   'atl_change_percentage': 201.93281,
#   'atl_date': '2019-11-18T03:09:35.959Z',
#   'roi': None,
#   'last_updated': '2026-06-14T06:57:27.638Z'},
#  {'id': 'world-liberty-financial',
#   'symbol': 'wlfi',
#   'name': 'World Liberty Financial',
#   'image': 'https://coin-images.coingecko.com/coins/images/50767/large/wlfi.png?1756438915',
#   'current_price': 0.058529,
#   'market_cap': 1858734200,
#   'market_cap_rank': 45,
#   'fully_diluted_valuation': 5849861339,
#   'total_volume': 25132022,
#   'high_24h': 0.05984,
#   'low_24h': 0.057871,
#   'price_change_24h': -0.001310478680908514,
#   'price_change_percentage_24h': -2.18998,
#   'market_cap_change_24h': -42452154.83297849,
#   'market_cap_change_percentage_24h': -2.23293,
#   'circulating_supply': 31773987311.0,
#   'total_supply': 100000000000.0,
#   'max_supply': 100000000000.0,
#   'ath': 0.331336,
#   'ath_change_percentage': -82.33533,
#   'ath_date': '2025-09-01T12:20:09.597Z',
#   'atl': 0.051632,
#   'atl_change_percentage': 13.35796,
#   'atl_date': '2026-05-02T06:24:04.639Z',
#   'roi': None,
#   'last_updated': '2026-06-14T06:57:32.058Z'},
#  {'id': 'mantle',
#   'symbol': 'mnt',
#   'name': 'Mantle',
#   'image': 'https://coin-images.coingecko.com/coins/images/30980/large/MNT_Token_Logo.png?1765516974',
#   'current_price': 0.5551,
#   'market_cap': 1833052647,
#   'market_cap_rank': 46,
#   'fully_diluted_valuation': 3452246769,
#   'total_volume': 13971870,
#   'high_24h': 0.557318,
#   'low_24h': 0.541082,
#   'price_change_24h': 0.0136953,
#   'price_change_percentage_24h': 2.52959,
#   'market_cap_change_24h': 45173901,
#   'market_cap_change_percentage_24h': 2.52668,
#   'circulating_supply': 3302294382.53684,
#   'total_supply': 6219316794.889999,
#   'max_supply': 6219316794.89,
#   'ath': 2.86,
#   'ath_change_percentage': -80.55843,
#   'ath_date': '2025-10-09T01:04:46.659Z',
#   'atl': 0.307978,
#   'atl_change_percentage': 80.23,
#   'atl_date': '2023-10-18T02:50:46.942Z',
#   'roi': None,
#   'last_updated': '2026-06-14T06:57:36.820Z'},
#  {'id': 'ondo-finance',
#   'symbol': 'ondo',
#   'name': 'Ondo',
#   'image': 'https://coin-images.coingecko.com/coins/images/26580/large/ONDO.png?1696525656',
#   'current_price': 0.358763,
#   'market_cap': 1746773840,
#   'market_cap_rank': 47,
#   'fully_diluted_valuation': 3587297654,
#   'total_volume': 98014650,
#   'high_24h': 0.3739,
#   'low_24h': 0.356391,
#   'price_change_24h': 0.00124276,
#   'price_change_percentage_24h': 0.34761,
#   'market_cap_change_24h': 9969432,
#   'market_cap_change_percentage_24h': 0.57401,
#   'circulating_supply': 4869330647.0,
#   'total_supply': 10000000000.0,
#   'max_supply': 10000000000.0,
#   'ath': 2.14,
#   'ath_change_percentage': -83.23658,
#   'ath_date': '2024-12-16T00:36:00.777Z',
#   'atl': 0.082171,
#   'atl_change_percentage': 336.60585,
#   'atl_date': '2024-01-18T12:14:30.524Z',
#   'roi': None,
#   'last_updated': '2026-06-14T06:57:24.061Z'},
#  {'id': 'worldcoin-wld',
#   'symbol': 'wld',
#   'name': 'Worldcoin',
#   'image': 'https://coin-images.coingecko.com/coins/images/31069/large/worldcoin.jpeg?1696529903',
#   'current_price': 0.512807,
#   'market_cap': 1744686299,
#   'market_cap_rank': 48,
#   'fully_diluted_valuation': 5131513319,
#   'total_volume': 767830774,
#   'high_24h': 0.531306,
#   'low_24h': 0.476638,
#   'price_change_24h': 0.03542834,
#   'price_change_percentage_24h': 7.42143,
#   'market_cap_change_24h': 122639366,
#   'market_cap_change_percentage_24h': 7.56078,
#   'circulating_supply': 3399944988.119858,
#   'total_supply': 10000000000.0,
#   'max_supply': 10000000000.0,
#   'ath': 11.74,
#   'ath_change_percentage': -95.62933,
#   'ath_date': '2024-03-10T00:10:42.330Z',
#   'atl': 0.230306,
#   'atl_change_percentage': 122.80927,
#   'atl_date': '2026-05-18T15:06:03.669Z',
#   'roi': None,
#   'last_updated': '2026-06-14T06:57:28.014Z'},
#  {'id': 'aster-2',
#   'symbol': 'aster',
#   'name': 'Aster',
#   'image': 'https://coin-images.coingecko.com/coins/images/69040/large/_ASTER.png?1757326782',
#   'current_price': 0.633146,
#   'market_cap': 1695342684,
#   'market_cap_rank': 49,
#   'fully_diluted_valuation': 4953325439,
#   'total_volume': 61289471,
#   'high_24h': 0.642008,
#   'low_24h': 0.633215,
#   'price_change_24h': -0.00477868440379392,
#   'price_change_percentage_24h': -0.7491,
#   'market_cap_change_24h': -14185419.267664194,
#   'market_cap_change_percentage_24h': -0.82979,
#   'circulating_supply': 2677260279.249776,
#   'total_supply': 7822218820.515041,
#   'max_supply': 8000000000.0,
#   'ath': 2.41,
#   'ath_change_percentage': -73.71459,
#   'ath_date': '2025-09-24T11:18:14.634Z',
#   'atl': 0.099713,
#   'atl_change_percentage': 534.96549,
#   'atl_date': '2025-09-17T12:05:36.771Z',
#   'roi': None,
#   'last_updated': '2026-06-14T06:57:29.459Z'},
#  {'id': 'ripple-usd',
#   'symbol': 'rlusd',
#   'name': 'Ripple USD',
#   'image': 'https://coin-images.coingecko.com/coins/images/39651/large/RLUSD_200x200_%281%29.png?1727376633',
#   'current_price': 0.999783,
#   'market_cap': 1638533165,
#   'market_cap_rank': 50,
#   'fully_diluted_valuation': 1638533165,
#   'total_volume': 39093072,
#   'high_24h': 1.0,
#   'low_24h': 0.999301,
#   'price_change_24h': -0.00032261591988092,
#   'price_change_percentage_24h': -0.03226,
#   'market_cap_change_24h': -454081.71326994896,
#   'market_cap_change_percentage_24h': -0.02771,
#   'circulating_supply': 1638895321.436209,
#   'total_supply': 1638895321.436209,
#   'max_supply': None,
#   'ath': 1.073,
#   'ath_change_percentage': -6.81446,
#   'ath_date': '2024-12-26T10:45:52.337Z',
#   'atl': 0.962292,
#   'atl_change_percentage': 3.88857,
#   'atl_date': '2024-12-18T04:40:40.880Z',
#   'roi': None,
#   'last_updated': '2026-06-14T06:57:35.025Z'},
#  {'id': 'polkadot',
#   'symbol': 'dot',
#   'name': 'Polkadot',
#   'image': 'https://coin-images.coingecko.com/coins/images/12171/large/polkadot.jpg?1766533446',
#   'current_price': 0.966857,
#   'market_cap': 1633323388,
#   'market_cap_rank': 51,
#   'fully_diluted_valuation': 1633323388,
#   'total_volume': 91171747,
#   'high_24h': 0.993074,
#   'low_24h': 0.96595,
#   'price_change_24h': -0.012460079302251237,
#   'price_change_percentage_24h': -1.27232,
#   'market_cap_change_24h': -20996744.006507874,
#   'market_cap_change_percentage_24h': -1.26921,
#   'circulating_supply': 1688587127.128923,
#   'total_supply': 1688587127.128923,
#   'max_supply': 2100000000.0,
#   'ath': 54.98,
#   'ath_change_percentage': -98.23948,
#   'ath_date': '2021-11-04T14:10:09.301Z',
#   'atl': 0.892875,
#   'atl_change_percentage': 8.4047,
#   'atl_date': '2026-06-06T05:05:21.076Z',
#   'roi': None,
#   'last_updated': '2026-06-14T06:57:30.544Z'},
#  {'id': 'uniswap',
#   'symbol': 'uni',
#   'name': 'Uniswap',
#   'image': 'https://coin-images.coingecko.com/coins/images/12504/large/uniswap-logo.png?1720676669',
#   'current_price': 2.53,
#   'market_cap': 1572792635,
#   'market_cap_rank': 52,
#   'fully_diluted_valuation': 2260830757,
#   'total_volume': 86089535,
#   'high_24h': 2.58,
#   'low_24h': 2.5,
#   'price_change_24h': 0.0244698,
#   'price_change_percentage_24h': 0.9774,
#   'market_cap_change_24h': 14627878,
#   'market_cap_change_percentage_24h': 0.93879,
#   'circulating_supply': 622075561.5538775,
#   'total_supply': 894210420.0329479,
#   'max_supply': 1000000000.0,
#   'ath': 44.92,
#   'ath_change_percentage': -94.3682,
#   'ath_date': '2021-05-03T05:25:04.822Z',
#   'atl': 1.03,
#   'atl_change_percentage': 145.56054,
#   'atl_date': '2020-09-17T01:20:38.214Z',
#   'roi': None,
#   'last_updated': '2026-06-14T06:57:32.749Z'},
#  {'id': 'okb',
#   'symbol': 'okb',
#   'name': 'OKB',
#   'image': 'https://coin-images.coingecko.com/coins/images/4463/large/WeChat_Image_20220118095654.png?1696505053',
#   'current_price': 74.63,
#   'market_cap': 1567396789,
#   'market_cap_rank': 53,
#   'fully_diluted_valuation': 1567396789,
#   'total_volume': 7814598,
#   'high_24h': 75.48,
#   'low_24h': 73.98,
#   'price_change_24h': -0.07698290207541447,
#   'price_change_percentage_24h': -0.10305,
#   'market_cap_change_24h': -545849.85546422,
#   'market_cap_change_percentage_24h': -0.03481,
#   'circulating_supply': 21000000.0,
#   'total_supply': 21000000.0,
#   'max_supply': 21000000.0,
#   'ath': 228.74,
#   'ath_change_percentage': -67.34127,
#   'ath_date': '2025-10-05T00:00:00.000Z',
#   'atl': 0.580608,
#   'atl_change_percentage': 12766.40769,
#   'atl_date': '2019-01-14T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2026-06-14T06:57:25.449Z'},
#  {'id': 'htx-dao',
#   'symbol': 'htx',
#   'name': 'HTX DAO',
#   'image': 'https://coin-images.coingecko.com/coins/images/35491/large/Frame_1321318576.png?1708908626',
#   'current_price': 1.68e-06,
#   'market_cap': 1518716245,
#   'market_cap_rank': 54,
#   'fully_diluted_valuation': 1518716245,
#   'total_volume': 71408626,
#   'high_24h': 1.7e-06,
#   'low_24h': 1.67e-06,
#   'price_change_24h': -1.7212034937e-08,
#   'price_change_percentage_24h': -1.01613,
#   'market_cap_change_24h': -15042631.938176155,
#   'market_cap_change_percentage_24h': -0.98077,
#   'circulating_supply': 905707664073577.8,
#   'total_supply': 905707664073577.8,
#   'max_supply': 999990000000000.0,
#   'ath': 3.75e-06,
#   'ath_change_percentage': -55.31105,
#   'ath_date': '2024-12-04T00:16:20.770Z',
#   'atl': 8.00816e-07,
#   'atl_change_percentage': 109.34949,
#   'atl_date': '2024-08-05T13:31:33.427Z',
#   'roi': None,
#   'last_updated': '2026-06-14T06:57:32.345Z'},
#  {'id': 'falcon-finance',
#   'symbol': 'usdf',
#   'name': 'Falcon USD',
#   'image': 'https://coin-images.coingecko.com/coins/images/54558/large/ff_200_X_200.png?1740741076',
#   'current_price': 0.995362,
#   'market_cap': 1460573944,
#   'market_cap_rank': 55,
#   'fully_diluted_valuation': 1460573944,
#   'total_volume': 686702,
#   'high_24h': 0.996736,
#   'low_24h': 0.994997,
#   'price_change_24h': -0.001174594823924568,
#   'price_change_percentage_24h': -0.11787,
#   'market_cap_change_24h': -133416.14754533768,
#   'market_cap_change_percentage_24h': -0.00913,
#   'circulating_supply': 1467315345.707553,
#   'total_supply': 1467315345.707553,
#   'max_supply': None,
#   'ath': 1.075,
#   'ath_change_percentage': -7.37243,
#   'ath_date': '2025-05-08T21:25:42.071Z',
#   'atl': 0.943422,
#   'atl_change_percentage': 5.50518,
#   'atl_date': '2025-07-08T10:16:34.749Z',
#   'roi': None,
#   'last_updated': '2026-06-14T06:57:25.861Z'},
#  {'id': 'pi-network',
#   'symbol': 'pi',
#   'name': 'Pi Network',
#   'image': 'https://coin-images.coingecko.com/coins/images/54342/large/pi_network.jpg?1739347576',
#   'current_price': 0.131754,
#   'market_cap': 1416021481,
#   'market_cap_rank': 56,
#   'fully_diluted_valuation': 2178494587,
#   'total_volume': 14945864,
#   'high_24h': 0.137747,
#   'low_24h': 0.127396,
#   'price_change_24h': 0.00430058,
#   'price_change_percentage_24h': 3.37424,
#   'market_cap_change_24h': 46584089,
#   'market_cap_change_percentage_24h': 3.4017,
#   'circulating_supply': 10741930368.05062,
#   'total_supply': 16526046720.07787,
#   'max_supply': 100000000000.0,
#   'ath': 2.99,
#   'ath_change_percentage': -95.59656,
#   'ath_date': '2025-02-26T16:41:03.732Z',
#   'atl': 0.118869,
#   'atl_change_percentage': 10.67492,
#   'atl_date': '2026-06-06T05:05:45.511Z',
#   'roi': None,
#   'last_updated': '2026-06-14T06:57:26.099Z'},
#  {'id': 'usdd',
#   'symbol': 'usdd',
#   'name': 'USDD',
#   'image': 'https://coin-images.coingecko.com/coins/images/25380/large/UUSD.jpg?1696524513',
# ...
#   'total_volume': 89660842,
#   'high_24h': 17.66,
#   'low_24h': 15.89,
#   'price_change_24h': -1.3856256753927312,
#   'price_change_percentage_24h': -7.90008,
#   'market_cap_change_24h': -60230172.19622409,
#   'market_cap_change_percentage_24h': -7.35142,
#   'circulating_supply': 46968818.84098753,
#   'total_supply': 80311309.15908088,
#   'max_supply': None,
#   'ath': 22.58,
#   'ath_change_percentage': -28.45447,
#   'ath_date': '2025-01-28T00:06:36.780Z',
#   'atl': 0.91975,
#   'atl_change_percentage': 1656.83772,
#   'atl_date': '2025-12-01T18:55:48.565Z',
#   'roi': None,
#   'last_updated': '2026-06-14T06:57:25.741Z'},
#  {'id': 'gatechain-token',
#   'symbol': 'gt',
#   'name': 'Gate',
#   'image': 'https://coin-images.coingecko.com/coins/images/8183/large/200X200.png?1735246724',
#   'current_price': 6.75,
#   'market_cap': 719188411,
#   'market_cap_rank': 84,
#   'fully_diluted_valuation': 819291272,
#   'total_volume': 2438563,
#   'high_24h': 6.78,
#   'low_24h': 6.59,
#   'price_change_24h': 0.059833,
#   'price_change_percentage_24h': 0.89379,
#   'market_cap_change_24h': 8968521,
#   'market_cap_change_percentage_24h': 1.26278,
#   'circulating_supply': 106483509.17747103,
#   'total_supply': 121304804.66747102,
#   'max_supply': 142622844.0,
#   'ath': 25.38,
#   'ath_change_percentage': -73.34008,
#   'ath_date': '2025-01-26T00:00:00.000Z',
#   'atl': 0.25754,
#   'atl_change_percentage': 2527.44939,
#   'atl_date': '2020-03-13T02:18:02.481Z',
#   'roi': None,
#   'last_updated': '2026-06-14T06:57:29.097Z'},
#  {'id': 'flare-networks',
#   'symbol': 'flr',
#   'name': 'Flare',
#   'image': 'https://coin-images.coingecko.com/coins/images/28624/large/FLR-icon200x200.png?1696527609',
#   'current_price': 0.00800719,
#   'market_cap': 685697145,
#   'market_cap_rank': 85,
#   'fully_diluted_valuation': 849752480,
#   'total_volume': 4177932,
#   'high_24h': 0.00804458,
#   'low_24h': 0.00780882,
#   'price_change_24h': 0.00011322,
#   'price_change_percentage_24h': 1.43425,
#   'market_cap_change_24h': 11212423,
#   'market_cap_change_percentage_24h': 1.66237,
#   'circulating_supply': 85523118859.41653,
#   'total_supply': 105984810978.4296,
#   'max_supply': None,
#   'ath': 0.150073,
#   'ath_change_percentage': -94.64058,
#   'ath_date': '2023-01-10T03:14:05.921Z',
#   'atl': 0.0064918,
#   'atl_change_percentage': 23.89534,
#   'atl_date': '2026-06-06T05:05:42.877Z',
#   'roi': None,
#   'last_updated': '2026-06-14T06:57:31.070Z'},
#  {'id': 'janus-henderson-anemoy-aaa-clo-fund',
#   'symbol': 'jaaa',
#   'name': 'Janus Henderson Anemoy AAA CLO Fund',
#   'image': 'https://coin-images.coingecko.com/coins/images/70446/large/jaaa.png?1762078666',
#   'current_price': 1.038,
#   'market_cap': 684444125,
#   'market_cap_rank': 86,
#   'fully_diluted_valuation': 684444125,
#   'total_volume': 0.0,
#   'high_24h': 1.038,
#   'low_24h': 1.038,
#   'price_change_24h': 0.0,
#   'price_change_percentage_24h': 0.0,
#   'market_cap_change_24h': 0.0,
#   'market_cap_change_percentage_24h': 0.0,
#   'circulating_supply': 659660673.338319,
#   'total_supply': 659660673.338319,
#   'max_supply': None,
#   'ath': 1.038,
#   'ath_change_percentage': -0.00029,
#   'ath_date': '2026-06-11T11:40:12.143Z',
#   'atl': 1.009,
#   'atl_change_percentage': 2.78191,
#   'atl_date': '2025-12-06T14:10:05.491Z',
#   'roi': None,
#   'last_updated': '2026-06-14T06:56:07.634Z'},
#  {'id': 'bianrensheng',
#   'symbol': '币安人生',
#   'name': '币安人生 (BinanceLife)',
#   'image': 'https://coin-images.coingecko.com/coins/images/69848/large/%E5%B8%81%E5%AE%89%E4%BA%BA%E7%94%9F.png?1759839225',
#   'current_price': 0.671724,
#   'market_cap': 671665744,
#   'market_cap_rank': 87,
#   'fully_diluted_valuation': 671665744,
#   'total_volume': 7294670,
#   'high_24h': 0.685571,
#   'low_24h': 0.668163,
#   'price_change_24h': -0.00565710781191775,
#   'price_change_percentage_24h': -0.83514,
#   'market_cap_change_24h': -6100826.264256716,
#   'market_cap_change_percentage_24h': -0.90014,
#   'circulating_supply': 1000000000.0,
#   'total_supply': 1000000000.0,
#   'max_supply': 1000000000.0,
#   'ath': 0.895319,
#   'ath_change_percentage': -25.03471,
#   'ath_date': '2026-06-07T10:25:46.588Z',
#   'atl': 0.03843448,
#   'atl_change_percentage': 1646.2928,
#   'atl_date': '2026-03-29T00:45:47.059Z',
#   'roi': None,
#   'last_updated': '2026-06-14T06:57:30.464Z'},
#  {'id': 'humanity',
#   'symbol': 'h',
#   'name': 'Humanity',
#   'image': 'https://coin-images.coingecko.com/coins/images/66811/large/H_tokenLogo_original.png?1750581252',
#   'current_price': 0.354255,
#   'market_cap': 648937665,
#   'market_cap_rank': 88,
#   'fully_diluted_valuation': 3555822822,
#   'total_volume': 113769347,
#   'high_24h': 0.380584,
#   'low_24h': 0.192799,
#   'price_change_24h': 0.161456,
#   'price_change_percentage_24h': 83.7429,
#   'market_cap_change_24h': 294324000,
#   'market_cap_change_percentage_24h': 82.99849,
#   'circulating_supply': 1825000000.0,
#   'total_supply': 10000000000.0,
#   'max_supply': 10000000000.0,
#   'ath': 0.843867,
#   'ath_change_percentage': -55.51139,
#   'ath_date': '2026-06-02T07:25:24.831Z',
#   'atl': 0.01810273,
#   'atl_change_percentage': 1973.85528,
#   'atl_date': '2025-06-27T01:20:39.339Z',
#   'roi': None,
#   'last_updated': '2026-06-14T06:57:26.443Z'},
#  {'id': 'just',
#   'symbol': 'jst',
#   'name': 'JUST',
#   'image': 'https://coin-images.coingecko.com/coins/images/11095/large/JUST.jpg?1696511035',
#   'current_price': 0.075106,
#   'market_cap': 641708360,
#   'market_cap_rank': 89,
#   'fully_diluted_valuation': 641708360,
#   'total_volume': 19493708,
#   'high_24h': 0.07731,
#   'low_24h': 0.074135,
#   'price_change_24h': -0.001796917949726723,
#   'price_change_percentage_24h': -2.3366,
#   'market_cap_change_24h': -15232948.909260392,
#   'market_cap_change_percentage_24h': -2.31877,
#   'circulating_supply': 8543764567.312736,
#   'total_supply': 8543764567.312736,
#   'max_supply': 9900000000.0,
#   'ath': 0.193254,
#   'ath_change_percentage': -61.10736,
#   'ath_date': '2021-04-05T04:34:23.454Z',
#   'atl': 0.00476275,
#   'atl_change_percentage': 1478.11523,
#   'atl_date': '2020-05-09T06:08:54.872Z',
#   'roi': None,
#   'last_updated': '2026-06-14T06:57:25.012Z'},
#  {'id': 'beldex',
#   'symbol': 'bdx',
#   'name': 'Beldex',
#   'image': 'https://coin-images.coingecko.com/coins/images/5111/large/Beldex.png?1696505631',
#   'current_price': 0.079784,
#   'market_cap': 617981654,
#   'market_cap_rank': 90,
#   'fully_diluted_valuation': 793643964,
#   'total_volume': 6745119,
#   'high_24h': 0.080471,
#   'low_24h': 0.076709,
#   'price_change_24h': 0.00287003,
#   'price_change_percentage_24h': 3.7315,
#   'market_cap_change_24h': 23114764,
#   'market_cap_change_percentage_24h': 3.8857,
#   'circulating_supply': 7738283083.510694,
#   'total_supply': 9937902884.453974,
#   'max_supply': None,
#   'ath': 0.450785,
#   'ath_change_percentage': -82.29254,
#   'ath_date': '2018-12-17T00:00:00.000Z',
#   'atl': 0.00027519,
#   'atl_change_percentage': 28906.80593,
#   'atl_date': '2019-11-01T11:05:12.090Z',
#   'roi': {'times': -0.6808657006618133,
#    'currency': 'usd',
#    'percentage': -68.08657006618132},
#   'last_updated': '2026-06-14T06:57:25.514Z'},
#  {'id': 'filecoin',
#   'symbol': 'fil',
#   'name': 'Filecoin',
#   'image': 'https://coin-images.coingecko.com/coins/images/12817/large/filecoin.png?1696512609',
#   'current_price': 0.767416,
#   'market_cap': 606081213,
#   'market_cap_rank': 91,
#   'fully_diluted_valuation': 1502504797,
#   'total_volume': 73290048,
#   'high_24h': 0.796662,
#   'low_24h': 0.765701,
#   'price_change_24h': -0.004176170207021324,
#   'price_change_percentage_24h': -0.54124,
#   'market_cap_change_24h': -3579969.728248596,
#   'market_cap_change_percentage_24h': -0.58721,
#   'circulating_supply': 789699953.0,
#   'total_supply': 1957704581.0,
#   'max_supply': None,
#   'ath': 236.84,
#   'ath_change_percentage': -99.67521,
#   'ath_date': '2021-04-01T13:29:41.564Z',
#   'atl': 0.677565,
#   'atl_change_percentage': 13.52597,
#   'atl_date': '2026-06-06T05:05:41.903Z',
#   'roi': None,
#   'last_updated': '2026-06-14T06:57:41.010Z'},
#  {'id': 'xdce-crowd-sale',
#   'symbol': 'xdc',
#   'name': 'XDC Network',
#   'image': 'https://coin-images.coingecko.com/coins/images/2912/large/xdc-icon.png?1696503661',
#   'current_price': 0.03029927,
#   'market_cap': 604478452,
#   'market_cap_rank': 92,
#   'fully_diluted_valuation': 1153569289,
#   'total_volume': 8017644,
#   'high_24h': 0.03064878,
#   'low_24h': 0.03002316,
#   'price_change_24h': -0.000161618159245629,
#   'price_change_percentage_24h': -0.53058,
#   'market_cap_change_24h': -3325270.90837574,
#   'market_cap_change_percentage_24h': -0.5471,
#   'circulating_supply': 19946688440.0,
#   'total_supply': 38065686425.1,
#   'max_supply': None,
#   'ath': 0.192754,
#   'ath_change_percentage': -84.33148,
#   'ath_date': '2021-08-21T04:39:48.324Z',
#   'atl': 0.00039532,
#   'atl_change_percentage': 7539.85351,
#   'atl_date': '2019-07-22T00:00:00.000Z',
#   'roi': {'times': 1.404026938630786,
#    'currency': 'eth',
#    'percentage': 140.40269386307858},
#   'last_updated': '2026-06-14T06:57:35.819Z'},
#  {'id': 'gho',
#   'symbol': 'gho',
#   'name': 'GHO',
#   'image': 'https://coin-images.coingecko.com/coins/images/30663/large/gho-token-logo.png?1720517092',
#   'current_price': 0.999006,
#   'market_cap': 598417947,
#   'market_cap_rank': 93,
#   'fully_diluted_valuation': 598417947,
#   'total_volume': 1050927,
#   'high_24h': 0.999388,
#   'low_24h': 0.998941,
#   'price_change_24h': -5.4445011265836e-05,
#   'price_change_percentage_24h': -0.00545,
#   'market_cap_change_24h': -24190.968933820724,
#   'market_cap_change_percentage_24h': -0.00404,
#   'circulating_supply': 599000000.0,
#   'total_supply': 599000000.0,
#   'max_supply': None,
#   'ath': 1.03,
#   'ath_change_percentage': -2.98633,
#   'ath_date': '2024-02-28T17:15:58.387Z',
#   'atl': 0.917065,
#   'atl_change_percentage': 8.94402,
#   'atl_date': '2023-10-24T04:41:04.568Z',
#   'roi': None,
#   'last_updated': '2026-06-14T06:57:24.147Z'},
#  {'id': 'jupiter-exchange-solana',
#   'symbol': 'jup',
#   'name': 'Jupiter',
#   'image': 'https://coin-images.coingecko.com/coins/images/34188/large/jup.png?1704266489',
#   'current_price': 0.170551,
#   'market_cap': 566625062,
#   'market_cap_rank': 94,
#   'fully_diluted_valuation': 1171102779,
#   'total_volume': 20627471,
#   'high_24h': 0.176043,
#   'low_24h': 0.170533,
#   'price_change_24h': -0.003462189121181847,
#   'price_change_percentage_24h': -1.98961,
#   'market_cap_change_24h': -11629008.065567136,
#   'market_cap_change_percentage_24h': -2.01106,
#   'circulating_supply': 3320312968.08,
#   'total_supply': 6862435158.391362,
#   'max_supply': 10000000000.0,
#   'ath': 2.0,
#   'ath_change_percentage': -91.45806,
#   'ath_date': '2024-01-31T15:02:47.304Z',
#   'atl': 0.135801,
#   'atl_change_percentage': 25.80176,
#   'atl_date': '2026-02-12T18:35:44.925Z',
#   'roi': None,
#   'last_updated': '2026-06-14T06:57:28.855Z'},
#  {'id': 'ylds',
#   'symbol': 'ylds',
#   'name': 'YLDS',
#   'image': 'https://coin-images.coingecko.com/coins/images/66486/large/YLDS.png?1772560579',
#   'current_price': 1.0,
#   'market_cap': 558324429,
#   'market_cap_rank': 95,
#   'fully_diluted_valuation': 558324429,
#   'total_volume': 2388599,
#   'high_24h': 1.0,
#   'low_24h': 0.999494,
#   'price_change_24h': 0.00019788,
#   'price_change_percentage_24h': 0.01979,
#   'market_cap_change_24h': 110437,
#   'market_cap_change_percentage_24h': 0.01978,
#   'circulating_supply': 558324429.49,
#   'total_supply': 558324429.49,
#   'max_supply': None,
#   'ath': 1.001,
#   'ath_change_percentage': -0.10838,
#   'ath_date': '2026-02-13T15:00:58.249Z',
#   'atl': 0.999202,
#   'atl_change_percentage': 0.07988,
#   'atl_date': '2025-11-16T12:26:29.488Z',
#   'roi': None,
#   'last_updated': '2026-06-14T06:57:26.206Z'},
#  {'id': 'usual-usd',
#   'symbol': 'usd0',
#   'name': 'Usual USD',
#   'image': 'https://coin-images.coingecko.com/coins/images/38272/large/USD0LOGO.png?1716962811',
#   'current_price': 0.998608,
#   'market_cap': 552807482,
#   'market_cap_rank': 96,
#   'fully_diluted_valuation': 552807482,
#   'total_volume': 542371,
#   'high_24h': 0.998712,
#   'low_24h': 0.998487,
#   'price_change_24h': 5.392e-05,
#   'price_change_percentage_24h': 0.0054,
#   'market_cap_change_24h': 29888,
#   'market_cap_change_percentage_24h': 0.00541,
#   'circulating_supply': 553578320.837345,
#   'total_supply': 553578320.837345,
#   'max_supply': None,
#   'ath': 1.33,
#   'ath_change_percentage': -24.67307,
#   'ath_date': '2024-07-12T08:28:59.311Z',
#   'atl': 0.962885,
#   'atl_change_percentage': 3.7101,
#   'atl_date': '2025-04-10T08:30:51.088Z',
#   'roi': None,
#   'last_updated': '2026-06-14T06:57:25.011Z'},
#  {'id': 'aptos',
#   'symbol': 'apt',
#   'name': 'Aptos',
#   'image': 'https://coin-images.coingecko.com/coins/images/26455/large/Aptos-Network-Symbol-Black-RGB-1x.png?1761789140',
#   'current_price': 0.661034,
#   'market_cap': 549846751,
#   'market_cap_rank': 97,
#   'fully_diluted_valuation': 795995662,
#   'total_volume': 47585245,
#   'high_24h': 0.682985,
#   'low_24h': 0.659179,
#   'price_change_24h': -0.004693599071462384,
#   'price_change_percentage_24h': -0.70503,
#   'market_cap_change_24h': -5491604.570951819,
#   'market_cap_change_percentage_24h': -0.98888,
#   'circulating_supply': 831798230.9016421,
#   'total_supply': 1204167854.984593,
#   'max_supply': 2100000000.0,
#   'ath': 19.92,
#   'ath_change_percentage': -96.67627,
#   'ath_date': '2023-01-26T14:25:17.390Z',
#   'atl': 0.609733,
#   'atl_change_percentage': 8.58987,
#   'atl_date': '2026-06-10T22:10:23.967Z',
#   'roi': None,
#   'last_updated': '2026-06-14T06:57:30.080Z'},
#  {'id': 'hash-2',
#   'symbol': 'hash',
#   'name': 'Provenance Blockchain',
#   'image': 'https://coin-images.coingecko.com/coins/images/66154/large/Hastra_Icon.png?1748497203',
#   'current_price': 0.01000318,
#   'market_cap': 541441965,
#   'market_cap_rank': 98,
#   'fully_diluted_valuation': 949709077,
#   'total_volume': 4952.47,
#   'high_24h': 0.010168,
#   'low_24h': 0.00998906,
#   'price_change_24h': -6.8145110358811e-05,
#   'price_change_percentage_24h': -0.67663,
#   'market_cap_change_24h': -3590393.883702874,
#   'market_cap_change_percentage_24h': -0.65875,
#   'circulating_supply': 54148510903.0,
#   'total_supply': 94978475357.64638,
#   'max_supply': 100000000000.0,
#   'ath': 0.060147,
#   'ath_change_percentage': -83.37347,
#   'ath_date': '2025-09-14T16:52:41.627Z',
#   'atl': 0.00868929,
#   'atl_change_percentage': 15.08827,
#   'atl_date': '2026-06-01T19:35:26.616Z',
#   'roi': None,
#   'last_updated': '2026-06-14T06:57:26.319Z'},
#  {'id': 'midnight-3',
#   'symbol': 'night',
#   'name': 'Midnight',
#   'image': 'https://coin-images.coingecko.com/coins/images/71015/large/midnight.png?1765193080',
#   'current_price': 0.03250292,
#   'market_cap': 539910892,
#   'market_cap_rank': 99,
#   'fully_diluted_valuation': 780246269,
#   'total_volume': 83744641,
#   'high_24h': 0.03497649,
#   'low_24h': 0.03132649,
#   'price_change_24h': -0.002273024545442856,
#   'price_change_percentage_24h': -6.5362,
#   'market_cap_change_24h': -38168360.7219913,
#   'market_cap_change_percentage_24h': -6.60262,
#   'circulating_supply': 16607399400.63495,
#   'total_supply': 24000000000.0,
#   'max_supply': 24000000000.0,
#   'ath': 0.118529,
#   'ath_change_percentage': -72.48907,
#   'ath_date': '2025-12-09T09:29:38.386Z',
#   'atl': 0.02378032,
#   'atl_change_percentage': 37.12362,
#   'atl_date': '2025-12-09T09:48:36.670Z',
#   'roi': None,
#   'last_updated': '2026-06-14T06:57:27.382Z'},
#  {'id': 'pump-fun',
#   'symbol': 'pump',
#   'name': 'Pump.fun',
#   'image': 'https://coin-images.coingecko.com/coins/images/67164/large/pump.jpg?1751949376',
#   'current_price': 0.00150681,
#   'market_cap': 524940797,
#   'market_cap_rank': 100,
#   'fully_diluted_valuation': 1294387100,
#   'total_volume': 28961720,
#   'high_24h': 0.00156555,
#   'low_24h': 0.00150112,
#   'price_change_24h': -3.5279579066225e-05,
#   'price_change_percentage_24h': -2.28777,
#   'market_cap_change_24h': -12900360.942431092,
#   'market_cap_change_percentage_24h': -2.39854,
#   'circulating_supply': 348253315197.8458,
#   'total_supply': 858715118869.0684,
#   'max_supply': 1000000000000.0,
#   'ath': 0.00881908,
#   'ath_change_percentage': -82.91416,
#   'ath_date': '2025-09-14T16:42:40.248Z',
#   'atl': 0.00131641,
#   'atl_change_percentage': 14.4643,
#   'atl_date': '2026-06-06T04:36:07.693Z',
#   'roi': None,
#   'last_updated': '2026-06-14T06:57:26.683Z'}]

# %%
# get_market_chart() 응답 내용(JSON) 확인
market_caps
# Out:
# [[1749945600000, 126263429802.95172],
#  [1750032000000, 127577707973.1105],
#  [1750118400000, 133168717149.84471],
#  [1750204800000, 127416681908.18704],
#  [1750291200000, 127820962755.39302],
#  [1750377600000, 127674651295.66653],
#  [1750464000000, 124953533243.95668],
#  [1750550400000, 120411151497.55313],
#  [1750636800000, 118672394254.47311],
#  [1750723200000, 127539548337.53386],
#  [1750809600000, 129018976028.34126],
#  [1750896000000, 128924835580.36104],
#  [1750982400000, 124230689777.04051],
#  [1751068800000, 126287954127.92236],
#  [1751155200000, 128959095356.2813],
#  [1751241600000, 130291214168.36028],
#  [1751328000000, 132156902495.55835],
#  [1751414400000, 128126705578.13293],
#  [1751500800000, 131977600025.21939],
#  [1751587200000, 133259962343.86203],
#  [1751673600000, 131144534229.89864],
#  [1751760000000, 130972769052.7035],
#  [1751846400000, 134151998248.59271],
#  [1751932800000, 134350852686.02478],
#  [1752019200000, 136497008281.73683],
#  [1752105600000, 142094073894.76715],
#  [1752192000000, 150138989600.80466],
#  [1752278400000, 161862097553.51227],
#  [1752364800000, 161796742917.52557],
#  [1752451200000, 167709014396.6901],
#  [1752537600000, 174691801800.57703],
#  [1752624000000, 172608862751.97787],
#  [1752710400000, 179784902655.3871],
#  [1752796800000, 206790617970.8479],
#  [1752883200000, 202056421574.12247],
#  [1752969600000, 203036588057.2096],
#  [1753056000000, 204531521314.64954],
#  [1753142400000, 210472490159.30972],
#  [1753228800000, 210230480631.16995],
#  [1753315200000, 188186759786.34775],
#  [1753401600000, 185920871104.63107],
#  [1753488000000, 185810977838.7848],
#  [1753574400000, 187641581965.9033],
#  [1753660800000, 191396539707.53333],
#  [1753747200000, 184768043390.20883],
#  [1753833600000, 185283974088.98334],
#  [1753920000000, 183489681384.74945],
#  [1754006400000, 179326407753.82678],
#  [1754092800000, 175651026151.1029],
#  [1754179200000, 164294692749.69305],
#  [1754265600000, 174843464841.0272],
#  [1754352000000, 182226168416.1388],
#  [1754438400000, 175947744749.02496],
#  [1754524800000, 177454281208.94727],
#  [1754611200000, 196586563136.16388],
#  [1754697600000, 195118577955.89972],
#  [1754784000000, 191448306716.0005],
#  [1754870400000, 188762634633.81073],
#  [1754956800000, 186208442509.3679],
#  [1755043200000, 193890996169.89874],
#  [1755129600000, 194924756464.55508],
#  [1755216000000, 183080844696.39935],
#  [1755302400000, 182823893074.88736],
#  [1755388800000, 184537083059.24762],
#  [1755475200000, 183971298108.38446],
#  [1755561600000, 181729332172.2824],
#  [1755648000000, 170168406125.4961],
#  [1755734400000, 175556019984.77844],
#  [1755820800000, 169235531134.4738],
#  [1755907200000, 182799236672.46982],
#  [1755993600000, 181178670544.90762],
#  [1756080000000, 180309158636.47443],
#  [1756166400000, 170267483807.62628],
#  [1756252800000, 179142732347.83713],
#  [1756339200000, 176555745920.97995],
#  [1756425600000, 176531083059.73718],
#  [1756512000000, 167986912659.00635],
#  [1756598400000, 167506975112.97137],
#  [1756684800000, 165199510162.63672],
#  [1756771200000, 163668082549.3002],
#  [1756857600000, 170017343347.65512],
#  [1756944000000, 169148418099.79056],
#  [1757030400000, 166553893839.9241],
#  [1757116800000, 167868172838.93118],
#  [1757203200000, 167555913519.96588],
#  [1757289600000, 171783435959.93152],
#  [1757376000000, 176863943138.69135],
#  [1757462400000, 175645238418.85535],
#  [1757548800000, 177831215415.68866],
#  [1757635200000, 181478948408.56073],
#  [1757721600000, 185122997953.71664],
#  [1757808000000, 186140756995.41547],
#  [1757894400000, 180683294841.68112],
#  [1757980800000, 178831483523.20224],
#  [1758067200000, 181512759461.20248],
#  [1758153600000, 184265198058.23386],
#  [1758240000000, 183975908931.03992],
#  [1758326400000, 178756914408.9819],
#  [1758412800000, 177890344746.8318],
#  [1758499200000, 177826889948.96225],
#  [1758585600000, 170400585443.59097],
#  [1758672000000, 169113142027.29474],
#  [1758758400000, 175079571412.7056],
#  [1758844800000, 163792649388.02155],
#  [1758931200000, 166695488560.7967],
#  [1759017600000, 168030941532.4935],
#  [1759104000000, 171433471696.45447],
#  [1759190400000, 172468504580.63516],
#  [1759276800000, 170189095368.76358],
#  [1759363200000, 176324742080.3806],
#  [1759449600000, 181705214116.74432],
#  [1759536000000, 182195760385.72156],
#  [1759622400000, 177802651636.65665],
#  [1759708800000, 177860837843.72095],
#  [1759795200000, 179189076600.90665],
#  [1759881600000, 171064100928.10922],
#  [1759968000000, 172611406399.91275],
#  [1760054400000, 167947986078.64722],
#  [1760140800000, 142892067212.53018],
#  [1760227200000, 142954842575.22836],
#  [1760313600000, 151364418493.13968],
#  [1760400000000, 156133172903.8652],
#  [1760486400000, 150211264226.71503],
#  [1760572800000, 144461490595.82288],
#  [1760659200000, 139315952355.05777],
#  [1760745600000, 137766791771.10846],
#  [1760832000000, 141516215270.95477],
#  [1760918400000, 143296898584.39374],
#  [1761004800000, 149320563020.78088],
#  [1761091200000, 145324368852.07394],
#  [1761177600000, 141709247798.4505],
#  [1761264000000, 143681621080.8351],
#  [1761350400000, 150337039547.91202],
#  [1761436800000, 155824923528.57858],
#  [1761523200000, 158916439662.16824],
#  [1761609600000, 158223409570.23694],
#  [1761696000000, 156523824436.52097],
#  [1761782400000, 153190098651.65286],
#  [1761868800000, 146186020714.36652],
#  [1761955200000, 150800414241.36542],
#  [1762041600000, 150534562819.6467],
#  [1762128000000, 151787404806.75775],
#  [1762214400000, 138661849487.4611],
#  [1762300800000, 133053897681.95323],
#  [1762387200000, 141129798148.7578],
#  [1762473600000, 132782422867.40593],
#  [1762560000000, 139260973653.4914],
#  [1762646400000, 137331703405.30908],
#  [1762732800000, 142067317205.8971],
#  [1762819200000, 151974237122.3631],
#  [1762905600000, 143727663286.9794],
#  [1762992000000, 143186972759.59644],
#  [1763078400000, 140562989006.31635],
#  [1763164800000, 135721912859.52069],
#  [1763251200000, 134518071270.12082],
#  [1763337600000, 133486160752.61365],
#  [1763424000000, 129949048741.95013],
#  [1763510400000, 133117730031.55574],
#  [1763596800000, 126853721222.81535],
#  [1763683200000, 120853150852.96416],
#  [1763769600000, 117518467990.35646],
#  [1763856000000, 117596582268.50671],
#  [1763942400000, 123296237500.01303],
#  [1764028800000, 134156981164.09805],
#  [1764115200000, 132509142343.04514],
#  [1764201600000, 134157655674.29039],
#  [1764288000000, 132789858572.43163],
#  [1764374400000, 131563297865.29353],
#  [1764460800000, 132904309840.30942],
#  [1764547200000, 130773769054.38704],
#  [1764633600000, 122590637081.77548],
#  [1764720000000, 130265478729.2633],
#  [1764806400000, 132937642111.7655],
#  [1764892800000, 126486491841.91081],
#  [1764979200000, 122781280853.37723],
#  [1765065600000, 122577456923.27518],
#  [1765152000000, 123040998729.40932],
#  [1765238400000, 125066913714.14474],
#  [1765324800000, 127322196940.53752],
#  [1765411200000, 123493871175.6185],
#  [1765497600000, 122945482685.17928],
#  [1765584000000, 121271367985.15312],
#  [1765670400000, 122081658806.46567],
#  [1765756800000, 119696831895.82625],
#  [1765843200000, 114709077203.17761],
#  [1765929600000, 116635881218.18115],
#  [1766016000000, 112627063671.41014],
#  [1766102400000, 109302270096.60616],
#  [1766188800000, 115440151450.5477],
#  [1766275200000, 117001210129.14806],
#  [1766361600000, 116507654772.39102],
#  [1766448000000, 115209591340.63138],
#  [1766534400000, 113540049924.98172],
#  [1766620800000, 112759823021.59952],
#  [1766707200000, 110961112657.54439],
#  [1766793600000, 111590253884.79008],
#  [1766880000000, 113432868120.26703],
#  [1766966400000, 112943419117.96327],
#  [1767052800000, 111915660113.13713],
#  [1767139200000, 113760103518.08258],
#  [1767225600000, 111584107850.57034],
#  [1767312000000, 113862299868.79008],
#  [1767398400000, 121857970095.58598],
#  [1767484800000, 122417798650.40025],
#  [1767571200000, 126829332926.84306],
#  [1767657600000, 143217645894.35986],
#  [1767744000000, 139893355179.23517],
#  [1767830400000, 131342647579.56671],
#  [1767916800000, 128890902402.58136],
#  [1768003200000, 127046182295.17743],
#  [1768089600000, 126788332730.89705],
#  [1768176000000, 125631699720.31146],
#  [1768262400000, 124566610364.54211],
#  [1768348800000, 130871637991.65312],
#  [1768435200000, 129865391288.69981],
#  [1768521600000, 126091557245.72693],
#  [1768608000000, 125743867931.1332],
#  [1768694400000, 125335465140.71304],
#  [1768780800000, 121358650247.96336],
#  [1768867200000, 120903244308.55229],
#  [1768953600000, 114737701418.28467],
#  [1769040000000, 118174939473.1962],
#  [1769126400000, 116745867275.0725],
#  [1769212800000, 116806714475.3337],
#  [1769299200000, 116446105795.45094],
#  [1769385600000, 111546255615.77956],
#  [1769472000000, 115887503699.2417],
#  [1769558400000, 116574716597.83336],
#  [1769644800000, 116052628994.01955],
#  [1769731200000, 109849188044.60716],
#  [1769817600000, 105432128839.02545],
#  [1769904000000, 99939565671.385],
#  [1769990400000, 97028843949.16516],
#  [1770076800000, 98619699555.84525],
#  [1770163200000, 95712683975.12364],
#  [1770249600000, 92410244673.49962],
#  [1770336000000, 74627934932.95325],
#  [1770422400000, 89768174961.8917],
#  [1770508800000, 86823610818.37268],
#  [1770595200000, 87440675892.7328],
#  [1770681600000, 87665589709.96698],
#  [1770768000000, 85271701641.28693],
#  [1770854400000, 83298868779.79366],
#  [1770940800000, 82929969245.25221],
#  [1771027200000, 85650029662.1184],
#  [1771113600000, 91976917572.85744],
#  [1771200000000, 89761800847.37251],
#  [1771286400000, 90610720943.03679],
#  [1771372800000, 89834881630.14792],
#  [1771459200000, 86399241397.57886],
#  [1771545600000, 85850017342.566],
#  [1771632000000, 87127134985.29282],
#  [1771718400000, 87411395033.64127],
#  [1771804800000, 84804267353.87541],
#  [1771891200000, 82526476193.37524],
#  [1771977600000, 82332540593.89131],
#  [1772064000000, 87170656589.21913],
#  [1772150400000, 85538873929.22694],
#  [1772236800000, 82808396104.64316],
#  [1772323200000, 84262604898.69641],
#  [1772409600000, 82518608292.31767],
#  [1772496000000, 85165748421.79579],
#  [1772582400000, 83177383072.09982],
#  [1772668800000, 87391300642.45819],
#  [1772755200000, 85837269777.23315],
#  [1772841600000, 83497860867.32414],
#  [1772928000000, 83045360925.16869],
#  [1773014400000, 82191986490.96655],
#  [1773100800000, 83420913725.49211],
#  [1773187200000, 84868343013.62126],
#  [1773273600000, 84824110149.1156],
#  [1773360000000, 84850665655.61424],
#  [1773446400000, 85618459862.1861],
#  [1773532800000, 86036778580.07281],
#  [1773619200000, 88605526347.89265],
#  [1773705600000, 94585455614.46468],
#  [1773792000000, 92990449113.53355],
#  [1773878400000, 89592778375.17401],
#  [1773964800000, 88659694188.07056],
#  [1774051200000, 88646559782.86374],
#  [1774137600000, 86940224871.74287],
#  [1774224000000, 85003739202.53421],
#  [1774310400000, 87747652207.63853],
#  [1774396800000, 86814706503.00735],
#  [1774483200000, 86689929456.57607],
#  [1774569600000, 83382836627.83237],
#  [1774656000000, 81208204456.41394],
#  [1774742400000, 81728179076.75484],
#  [1774828800000, 81399211411.3436],
#  [1774915200000, 81124053187.77298],
#  [1775001600000, 82220833777.49088],
#  [1775088000000, 82786500101.54463],
#  [1775174400000, 80994024817.14325],
#  [1775260800000, 80932878683.90056],
#  [1775347200000, 80718975209.79355],
#  [1775433600000, 81339347299.81769],
#  [1775520000000, 81119881405.69434],
#  [1775606400000, 84708522165.9529],
#  [1775692800000, 82449126175.14423],
#  [1775779200000, 82532083755.5244],
#  [1775865600000, 83304017566.26328],
#  [1775952000000, 83225262811.3884],
#  [1776038400000, 81375805431.99823],
#  [1776124800000, 84515744397.96951],
#  [1776211200000, 83643937463.76628],
#  [1776297600000, 85681242844.2964],
#  [1776384000000, 89462359830.41489],
#  [1776470400000, 90950429911.1164],
#  [1776556800000, 88214730680.3619],
#  [1776643200000, 85830727383.02965],
#  [1776729600000, 87727877250.9485],
#  [1776816000000, 88113321432.13998],
#  [1776902400000, 88062433372.33125],
#  [1776988800000, 88635500208.82472],
#  [1777075200000, 88435453017.76625],
#  [1777161600000, 87849887497.22456],
#  [1777248000000, 88268288444.80072],
#  [1777334400000, 86340404478.89772],
#  [1777420800000, 85164100381.18465],
#  [1777507200000, 84442228081.86342],
#  [1777593600000, 84339690066.82967],
#  [1777680000000, 85404826712.98979],
#  [1777766400000, 86215728259.17459],
#  [1777852800000, 85761528563.11829],
#  [1777939200000, 85956736783.37155],
#  [1778025600000, 87331561992.18446],
#  [1778112000000, 87989453388.00082],
#  [1778198400000, 85737170169.69716],
#  [1778284800000, 87577174753.12872],
#  [1778371200000, 87756578534.77168],
#  [1778457600000, 91026505768.2578],
#  [1778544000000, 91235013599.64273],
#  [1778630400000, 88751556526.79672],
#  [1778716800000, 88056604495.45946],
#  [1778803200000, 91733042692.21188],
#  [1778889600000, 88665626011.51823],
#  [1778976000000, 87404378405.14095],
#  [1779062400000, 86369993729.42601],
#  [1779148800000, 85907590089.02913],
#  [1779235200000, 84173830457.5356],
#  [1779321600000, 84397617318.13403],
#  [1779408000000, 84873705536.99689],
#  [1779494400000, 82490960993.12318],
#  [1779580800000, 83934756177.2623],
#  [1779667200000, 83580208064.54935],
#  [1779753600000, 83447079531.94699],
#  [1779840000000, 82155641500.75327],
#  [1779926400000, 80796761102.71222],
#  [1780012800000, 81378525702.38968],
#  [1780099200000, 82317367661.94856],
#  [1780185600000, 82925477846.10121],
#  [1780272000000, 82480263654.6071],
#  [1780358400000, 80321547592.52113],
#  [1780444800000, 74896385149.76274],
#  [1780531200000, 74425640226.43062],
#  [1780617600000, 72357553703.75685],
#  [1780704000000, 67980319391.30056],
#  [1780790400000, 67841665695.31133],
#  [1780876800000, 71654313411.4677],
#  [1780963200000, 72471083694.817],
#  [1781049600000, 70592140687.96422],
#  [1781136000000, 68039043437.920166],
#  [1781222400000, 70801096617.90039],
#  [1781308800000, 70180044889.55016],
#  [1781395200000, 71285987007.62492],
#  [1781420312000, 71116866885.31178]]
